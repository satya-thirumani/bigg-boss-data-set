# %% [markdown]
# <a href="https://www.kaggle.com/thirumani/shark-tank-india-analysis?scriptVersionId=87731611" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Shark Tank India Exploratory Data Analysis (EDA)
#
# ## Dataset https://www.kaggle.com/thirumani/shark-tank-india

# %%
import datetime
print("Notebook was last executed on:", datetime.date.today().strftime("%Y-%b-%d"))
# Out:
# Notebook was last executed on: 2022-Feb-13

# %% [markdown]
# ### Importing Required Python Libraries

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 50)

import matplotlib.pyplot as plt
import seaborn as sns
from babel.numbers import format_currency
from wordcloud import WordCloud

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Check and import dataset

# %%
! ls -l /kaggle/input/shark-tank-india
shark_tank = pd.read_csv('/kaggle/input/shark-tank-india/Shark Tank India.csv', encoding = "ISO-8859-1")

nRow, nCol = shark_tank.shape
print(f'\nThere are {nRow} rows and {nCol} columns in the dataset')
# Out:
# total 16
# -rw-r--r-- 1 nobody nogroup 13673 Feb 13 14:46 'Shark Tank India.csv'
#
# There are 117 rows and 44 columns in the dataset

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
shark_tank.head(5)
# Out:
#    Season Number  Episode Number                Episode Title  Pitch Number  \
# 0              1               1  Badlegi Business Ki Tasveer             1
# 1              1               1  Badlegi Business Ki Tasveer             2
# 2              1               1  Badlegi Business Ki Tasveer             3
# 3              1               2      Insaan, Ideas Aur Sapne             4
# 4              1               2      Insaan, Ideas Aur Sapne             5
#
#           Startup Name             Industry  \
# 0       BluePine Foods                 Food
# 1        Booz Scooters  Electrical Vehicles
# 2  Heart up my Sleeves       Beauty/Fashion
# 3           Tagz Foods                 Food
# 4       Head and Heart            Education
#
#                             Business Description  Number of Presenters  \
# 0                                   Frozen Momos                   3.0
# 1  Renting e-bike for mobility in private spaces                   1.0
# 2                             Detachable Sleeves                   1.0
# 3                           Healthy Potato Chips                   2.0
# 4                       Brain Development Course                   4.0
#
#    Male Presenter  Female Presenter  Yearly Revenue  Monthly Sales  \
# 0             2.0               1.0            95.0       800000.0
# 1             1.0               NaN             4.0        40000.0
# 2             NaN               1.0             NaN       200000.0
# 3             2.0               NaN          1200.0            NaN
# 4             1.0               3.0            30.0            NaN
#
#    Gross Margin  Original Ask Amount  Original Ask Equity Valuation Requested  \
# 0           NaN                 50.0                  5.0                1000
# 1           NaN                 40.0                 15.0                 267
# 2           NaN                 25.0                 10.0                 250
# 3          48.0                 70.0                  1.0                7000
# 4           NaN                 50.0                  5.0                1000
#
#    Received Offer  Accepted Offer  Total Deal Amount  Total Deal Equity  \
# 0             1.0             1.0               75.0              16.00
# 1             1.0             1.0               40.0              50.00
# 2             1.0             1.0               25.0              30.00
# 3             1.0             1.0               70.0               2.75
# 4             0.0             NaN                NaN                NaN
#
#    Total Deal Debt  Valuation Offered  Ashneer Investment Amount  \
# 0              NaN              469.0                       25.0
# 1              NaN               80.0                       20.0
# 2              NaN               83.0                        0.0
# 3              NaN             2545.0                       70.0
# 4              NaN                NaN                        NaN
#
#    Ashneer Investment Equity  Ashneer Debt Amount  Namita Investment Amount  \
# 0                       5.33                  NaN                       0.0
# 1                      25.00                  NaN                       0.0
# 2                       0.00                  NaN                       0.0
# 3                       2.75                  NaN                       0.0
# 4                        NaN                  NaN                       NaN
#
#    Namita Investment Equity  Namita Debt Amount  Anupam Investment Amount  \
# 0                       0.0                 NaN                       0.0
# 1                       0.0                 NaN                       0.0
# 2                       0.0                 NaN                      12.5
# 3                       0.0                 NaN                       0.0
# 4                       NaN                 NaN                       NaN
#
#    Anupam Investment Equity  Anupam Debt Amount  Vineeta Investment Amount  \
# 0                       0.0                 NaN                       25.0
# 1                       0.0                 NaN                       20.0
# 2                      15.0                 NaN                       12.5
# 3                       0.0                 NaN                        0.0
# 4                       NaN                 NaN                        NaN
#
#    Vineeta Investment Equity  Vineeta Debt Amount  Aman Investment Amount  \
# 0                       5.33                  NaN                    25.0
# 1                      25.00                  NaN                     0.0
# 2                      15.00                  NaN                     0.0
# 3                       0.00                  NaN                     0.0
# 4                        NaN                  NaN                     NaN
#
#    Aman Investment Equity  Aman Debt Amount  Peyush Investment Amount  \
# 0                    5.33               NaN                       NaN
# 1                    0.00               NaN                       NaN
# 2                    0.00               NaN                       NaN
# 3                    0.00               NaN                       NaN
# 4                     NaN               NaN                       NaN
#
#    Peyush Investment Equity  Peyush Debt Amount  Ghazal Investment Amount  \
# 0                       NaN                 NaN                       NaN
# 1                       NaN                 NaN                       NaN
# 2                       NaN                 NaN                       NaN
# 3                       NaN                 NaN                       NaN
# 4                       NaN                 NaN                       NaN
#
#    Ghazal Investment Equity  Ghazal Debt Amount  Number of sharks in deal
# 0                       NaN                 NaN                       3.0
# 1                       NaN                 NaN                       2.0
# 2                       NaN                 NaN                       2.0
# 3                       NaN                 NaN                       1.0
# 4                       NaN                 NaN                       NaN

# %%
shark_tank.tail(10).T
# Out:
#                                             107         108         109  \
# Season Number                                 1           1           1
# Episode Number                               33          33          33
# Episode Title                               NaN         NaN         NaN
# Pitch Number                                108         109         110
# Startup Name                             Mavi's  Tweek Labs      Proxgy
# Industry                                   Food         NaN  Technology
# Business Description       Vegan Fermented Food  Sportswear          VR
# Number of Presenters                        NaN         NaN         NaN
# Male Presenter                              NaN         NaN         NaN
# Female Presenter                            NaN         NaN         NaN
# Yearly Revenue                              NaN         NaN         NaN
# Monthly Sales                               NaN         NaN         NaN
# Gross Margin                                NaN         NaN         NaN
# Original Ask Amount                         NaN         NaN         NaN
# Original Ask Equity                         NaN         NaN         NaN
# Valuation Requested                         NaN         NaN         NaN
# Received Offer                              NaN         1.0         1.0
# Accepted Offer                              NaN         1.0         1.0
# Total Deal Amount                           NaN        60.0       100.0
# Total Deal Equity                           NaN        10.0        10.0
# Total Deal Debt                             NaN         NaN         NaN
# Valuation Offered                           NaN       600.0      1000.0
# Ashneer Investment Amount                   NaN         NaN         NaN
# Ashneer Investment Equity                   NaN         NaN         NaN
# Ashneer Debt Amount                         NaN         NaN         NaN
# Namita Investment Amount                    NaN         NaN         NaN
# Namita Investment Equity                    NaN         NaN         NaN
# Namita Debt Amount                          NaN         NaN         NaN
# Anupam Investment Amount                    NaN         NaN         NaN
# Anupam Investment Equity                    NaN         NaN         NaN
# Anupam Debt Amount                          NaN         NaN         NaN
# Vineeta Investment Amount                   NaN         NaN         NaN
# Vineeta Investment Equity                   NaN         NaN         NaN
# Vineeta Debt Amount                         NaN         NaN         NaN
# Aman Investment Amount                      NaN         NaN         NaN
# Aman Investment Equity                      NaN         NaN         NaN
# Aman Debt Amount                            NaN         NaN         NaN
# Peyush Investment Amount                    NaN         NaN         NaN
# Peyush Investment Equity                    NaN         NaN         NaN
# Peyush Debt Amount                          NaN         NaN         NaN
# Ghazal Investment Amount                    NaN         NaN         NaN
# Ghazal Investment Equity                    NaN         NaN         NaN
# Ghazal Debt Amount                          NaN         NaN         NaN
# Number of sharks in deal                    NaN         NaN         NaN
#
#                                           110  \
# Season Number                               1
# Episode Number                             34
# Episode Title                             NaN
# Pitch Number                              111
# Startup Name               Nomad Food Project
# Industry                                 Food
# Business Description               Bacon Jams
# Number of Presenters                      NaN
# Male Presenter                            NaN
# Female Presenter                          NaN
# Yearly Revenue                            NaN
# Monthly Sales                             NaN
# Gross Margin                              NaN
# Original Ask Amount                       NaN
# Original Ask Equity                       NaN
# Valuation Requested                       NaN
# Received Offer                            1.0
# Accepted Offer                            1.0
# Total Deal Amount                        40.0
# Total Deal Equity                        20.0
# Total Deal Debt                           NaN
# Valuation Offered                       200.0
# Ashneer Investment Amount                 NaN
# Ashneer Investment Equity                 NaN
# Ashneer Debt Amount                       NaN
# Namita Investment Amount                  NaN
# Namita Investment Equity                  NaN
# Namita Debt Amount                        NaN
# Anupam Investment Amount                  NaN
# Anupam Investment Equity                  NaN
# Anupam Debt Amount                        NaN
# Vineeta Investment Amount                 NaN
# Vineeta Investment Equity                 NaN
# Vineeta Debt Amount                       NaN
# Aman Investment Amount                    NaN
# Aman Investment Equity                    NaN
# Aman Debt Amount                          NaN
# Peyush Investment Amount                  NaN
# Peyush Investment Equity                  NaN
# Peyush Debt Amount                        NaN
# Ghazal Investment Amount                  NaN
# Ghazal Investment Equity                  NaN
# Ghazal Debt Amount                        NaN
# Number of sharks in deal                  NaN
#
#                                                            111  \
# Season Number                                                1
# Episode Number                                              34
# Episode Title                                              NaN
# Pitch Number                                               112
# Startup Name                                       Twee in One
# Industry                                                   NaN
# Business Description       Reversible and convertible clothing
# Number of Presenters                                       NaN
# Male Presenter                                             NaN
# Female Presenter                                           NaN
# Yearly Revenue                                             NaN
# Monthly Sales                                              NaN
# Gross Margin                                               NaN
# Original Ask Amount                                        NaN
# Original Ask Equity                                        NaN
# Valuation Requested                                        NaN
# Received Offer                                             NaN
# Accepted Offer                                             NaN
# Total Deal Amount                                          NaN
# Total Deal Equity                                          NaN
# Total Deal Debt                                            NaN
# Valuation Offered                                          NaN
# Ashneer Investment Amount                                  NaN
# Ashneer Investment Equity                                  NaN
# Ashneer Debt Amount                                        NaN
# Namita Investment Amount                                   NaN
# Namita Investment Equity                                   NaN
# Namita Debt Amount                                         NaN
# Anupam Investment Amount                                   NaN
# Anupam Investment Equity                                   NaN
# Anupam Debt Amount                                         NaN
# Vineeta Investment Amount                                  NaN
# Vineeta Investment Equity                                  NaN
# Vineeta Debt Amount                                        NaN
# Aman Investment Amount                                     NaN
# Aman Investment Equity                                     NaN
# Aman Debt Amount                                           NaN
# Peyush Investment Amount                                   NaN
# Peyush Investment Equity                                   NaN
# Peyush Debt Amount                                         NaN
# Ghazal Investment Amount                                   NaN
# Ghazal Investment Equity                                   NaN
# Ghazal Debt Amount                                         NaN
# Number of sharks in deal                                   NaN
#
#                                            112                     113  \
# Season Number                                1                       1
# Episode Number                              34                      34
# Episode Title                              NaN                     NaN
# Pitch Number                               113                     114
# Startup Name                     Green Protein                 On2Cook
# Industry                                   NaN                     NaN
# Business Description       Plant-Based Protein  Fastest Cooking Device
# Number of Presenters                       NaN                     NaN
# Male Presenter                             NaN                     NaN
# Female Presenter                           NaN                     NaN
# Yearly Revenue                             NaN                     NaN
# Monthly Sales                              NaN                     NaN
# Gross Margin                               NaN                     NaN
# Original Ask Amount                        NaN                     NaN
# Original Ask Equity                        NaN                     NaN
# Valuation Requested                        NaN                     NaN
# Received Offer                             NaN                     NaN
# Accepted Offer                             NaN                     NaN
# Total Deal Amount                          NaN                     NaN
# Total Deal Equity                          NaN                     NaN
# Total Deal Debt                            NaN                     NaN
# Valuation Offered                          NaN                     NaN
# Ashneer Investment Amount                  NaN                     NaN
# Ashneer Investment Equity                  NaN                     NaN
# Ashneer Debt Amount                        NaN                     NaN
# Namita Investment Amount                   NaN                     NaN
# Namita Investment Equity                   NaN                     NaN
# Namita Debt Amount                         NaN                     NaN
# Anupam Investment Amount                   NaN                     NaN
# Anupam Investment Equity                   NaN                     NaN
# Anupam Debt Amount                         NaN                     NaN
# Vineeta Investment Amount                  NaN                     NaN
# Vineeta Investment Equity                  NaN                     NaN
# Vineeta Debt Amount                        NaN                     NaN
# Aman Investment Amount                     NaN                     NaN
# Aman Investment Equity                     NaN                     NaN
# Aman Debt Amount                           NaN                     NaN
# Peyush Investment Amount                   NaN                     NaN
# Peyush Investment Equity                   NaN                     NaN
# Peyush Debt Amount                         NaN                     NaN
# Ghazal Investment Amount                   NaN                     NaN
# Ghazal Investment Equity                   NaN                     NaN
# Ghazal Debt Amount                         NaN                     NaN
# Number of sharks in deal                   NaN                     NaN
#
#                                      114              115  \
# Season Number                          1                1
# Episode Number                        35               35
# Episode Title                        NaN              NaN
# Pitch Number                         115              116
# Startup Name               Jain Shikanji            Woloo
# Industry                             NaN              NaN
# Business Description            Lemonade  Washroom Finder
# Number of Presenters                 NaN              NaN
# Male Presenter                       NaN              NaN
# Female Presenter                     NaN              NaN
# Yearly Revenue                       NaN              NaN
# Monthly Sales                        NaN              NaN
# Gross Margin                         NaN              NaN
# Original Ask Amount                  NaN              NaN
# Original Ask Equity                  NaN              NaN
# Valuation Requested                  NaN              NaN
# Received Offer                       1.0              NaN
# Accepted Offer                       1.0              NaN
# Total Deal Amount                   40.0              NaN
# Total Deal Equity                   30.0              NaN
# Total Deal Debt                      NaN              NaN
# Valuation Offered                  133.0              NaN
# Ashneer Investment Amount            NaN              NaN
# Ashneer Investment Equity            NaN              NaN
# Ashneer Debt Amount                  NaN              NaN
# Namita Investment Amount             NaN              NaN
# Namita Investment Equity             NaN              NaN
# Namita Debt Amount                   NaN              NaN
# Anupam Investment Amount             NaN              NaN
# Anupam Investment Equity             NaN              NaN
# Anupam Debt Amount                   NaN              NaN
# Vineeta Investment Amount            NaN              NaN
# Vineeta Investment Equity            NaN              NaN
# Vineeta Debt Amount                  NaN              NaN
# Aman Investment Amount               NaN              NaN
# Aman Investment Equity               NaN              NaN
# Aman Debt Amount                     NaN              NaN
# Peyush Investment Amount             NaN              NaN
# Peyush Investment Equity             NaN              NaN
# Peyush Debt Amount                   NaN              NaN
# Ghazal Investment Amount             NaN              NaN
# Ghazal Investment Equity             NaN              NaN
# Ghazal Debt Amount                   NaN              NaN
# Number of sharks in deal             NaN              NaN
#
#                                             116
# Season Number                                 1
# Episode Number                               35
# Episode Title                               NaN
# Pitch Number                                117
# Startup Name                       Elcare India
# Industry                                    NaN
# Business Description       Carenting for Elders
# Number of Presenters                        NaN
# Male Presenter                              NaN
# Female Presenter                            NaN
# Yearly Revenue                              NaN
# Monthly Sales                               NaN
# Gross Margin                                NaN
# Original Ask Amount                         NaN
# Original Ask Equity                         NaN
# Valuation Requested                         NaN
# Received Offer                              NaN
# Accepted Offer                              NaN
# Total Deal Amount                           NaN
# Total Deal Equity                           NaN
# Total Deal Debt                             NaN
# Valuation Offered                           NaN
# Ashneer Investment Amount                   NaN
# Ashneer Investment Equity                   NaN
# Ashneer Debt Amount                         NaN
# Namita Investment Amount                    NaN
# Namita Investment Equity                    NaN
# Namita Debt Amount                          NaN
# Anupam Investment Amount                    NaN
# Anupam Investment Equity                    NaN
# Anupam Debt Amount                          NaN
# Vineeta Investment Amount                   NaN
# Vineeta Investment Equity                   NaN
# Vineeta Debt Amount                         NaN
# Aman Investment Amount                      NaN
# Aman Investment Equity                      NaN
# Aman Debt Amount                            NaN
# Peyush Investment Amount                    NaN
# Peyush Investment Equity                    NaN
# Peyush Debt Amount                          NaN
# Ghazal Investment Amount                    NaN
# Ghazal Investment Equity                    NaN
# Ghazal Debt Amount                          NaN
# Number of sharks in deal                    NaN

# %%
shark_tank.sample(10)
# Out:
#      Season Number  Episode Number            Episode Title  Pitch Number  \
# 72               1              23                      NaN            73
# 33               1              12                      NaN            34
# 98               1              31                      NaN            99
# 106              1              33                      NaN           107
# 71               1              23                      NaN            72
# 3                1               2  Insaan, Ideas Aur Sapne             4
# 113              1              34                      NaN           114
# 68               1              22                      NaN            69
# 45               1              16                      NaN            46
# 18               1               7   A Never Give Up Spirit            19
#
#            Startup Name        Industry               Business Description  \
# 72         Urban Monkey             NaN                         Streetwear
# 33       Auli Lifestyle             NaN                 Ayurvedic Products
# 98           Scrapshala             NaN  Handmade Reusable Scrap Materials
# 106       Colour Me Mad             NaN                            Insoles
# 71         Namhya Foods             NaN            Ayurvedic Enriched Food
# 3            Tagz Foods            Food               Healthy Potato Chips
# 113             On2Cook             NaN             Fastest Cooking Device
# 68       Poo de Cologne  Beauty/Fashion   Toilet Spray with Essential Oils
# 45         Bamboo India             NaN                    Bamboo Products
# 18   Raising Superstars       Education              Child Development App
#
#      Number of Presenters  Male Presenter  Female Presenter  Yearly Revenue  \
# 72                    NaN             NaN               NaN             NaN
# 33                    NaN             NaN               NaN             NaN
# 98                    NaN             NaN               NaN             NaN
# 106                   NaN             NaN               NaN             NaN
# 71                    NaN             NaN               NaN             NaN
# 3                     2.0             2.0               NaN          1200.0
# 113                   NaN             NaN               NaN             NaN
# 68                    NaN             NaN               NaN             NaN
# 45                    NaN             NaN               NaN             NaN
# 18                    2.0             1.0               1.0             NaN
#
#      Monthly Sales  Gross Margin  Original Ask Amount  Original Ask Equity  \
# 72             NaN           NaN                100.0                  1.0
# 33             NaN           NaN                 75.0                  4.0
# 98             NaN           NaN                 50.0                 10.0
# 106            NaN           NaN                 40.0                 10.0
# 71             NaN           NaN                100.0                  5.0
# 3              NaN          48.0                 70.0                  1.0
# 113            NaN           NaN                  NaN                  NaN
# 68             NaN           NaN                 75.0                  5.0
# 45             NaN           NaN                 80.0                  4.0
# 18             NaN           NaN                100.0                  2.0
#
#     Valuation Requested  Received Offer  Accepted Offer  Total Deal Amount  \
# 72                10000             NaN             NaN                NaN
# 33                 1875             1.0             1.0               75.0
# 98                  500             NaN             NaN                NaN
# 106                 400             1.0             1.0               40.0
# 71                 2000             1.0             1.0               50.0
# 3                  7000             1.0             1.0               70.0
# 113                 NaN             NaN             NaN                NaN
# 68                 1500             NaN             NaN                NaN
# 45                 2000             1.0             1.0               50.0
# 18                 5000             1.0             1.0              100.0
#
#      Total Deal Equity  Total Deal Debt  Valuation Offered  \
# 72                 NaN              NaN                NaN
# 33               15.00              NaN              500.0
# 98                 NaN              NaN                NaN
# 106              25.00              NaN              160.0
# 71               10.00             50.0              500.0
# 3                 2.75              NaN             2545.0
# 113                NaN              NaN                NaN
# 68                 NaN              NaN                NaN
# 45                3.50             30.0             1429.0
# 18                4.00              NaN             2500.0
#
#      Ashneer Investment Amount  Ashneer Investment Equity  \
# 72                         NaN                        NaN
# 33                         NaN                        NaN
# 98                         NaN                        NaN
# 106                        NaN                        NaN
# 71                         NaN                        NaN
# 3                         70.0                       2.75
# 113                        NaN                        NaN
# 68                         NaN                        NaN
# 45                         NaN                        NaN
# 18                        50.0                       2.00
#
#      Ashneer Debt Amount  Namita Investment Amount  Namita Investment Equity  \
# 72                   NaN                       NaN                       NaN
# 33                   NaN                       NaN                       NaN
# 98                   NaN                       NaN                       NaN
# 106                  NaN                       NaN                       NaN
# 71                   NaN                       NaN                       NaN
# 3                    NaN                       0.0                       0.0
# 113                  NaN                       NaN                       NaN
# 68                   NaN                       NaN                       NaN
# 45                   NaN                       NaN                       NaN
# 18                   NaN                       0.0                       0.0
#
#      Namita Debt Amount  Anupam Investment Amount  Anupam Investment Equity  \
# 72                  NaN                       NaN                       NaN
# 33                  NaN                       NaN                       NaN
# 98                  NaN                       NaN                       NaN
# 106                 NaN                       NaN                       NaN
# 71                  NaN                       NaN                       NaN
# 3                   NaN                       0.0                       0.0
# 113                 NaN                       NaN                       NaN
# 68                  NaN                       NaN                       NaN
# 45                  NaN                       NaN                       NaN
# 18                  NaN                       0.0                       0.0
#
#      Anupam Debt Amount  Vineeta Investment Amount  Vineeta Investment Equity  \
# 72                  NaN                        NaN                        NaN
# 33                  NaN                        NaN                        NaN
# 98                  NaN                        NaN                        NaN
# 106                 NaN                        NaN                        NaN
# 71                  NaN                        NaN                        NaN
# 3                   NaN                        0.0                        0.0
# 113                 NaN                        NaN                        NaN
# 68                  NaN                        NaN                        NaN
# 45                  NaN                        NaN                        NaN
# 18                  NaN                        0.0                        0.0
#
#      Vineeta Debt Amount  Aman Investment Amount  Aman Investment Equity  \
# 72                   NaN                     NaN                     NaN
# 33                   NaN                     NaN                     NaN
# 98                   NaN                     NaN                     NaN
# 106                  NaN                     NaN                     NaN
# 71                   NaN                     NaN                     NaN
# 3                    NaN                     0.0                     0.0
# 113                  NaN                     NaN                     NaN
# 68                   NaN                     NaN                     NaN
# 45                   NaN                     NaN                     NaN
# 18                   NaN                    50.0                     2.0
#
#      Aman Debt Amount  Peyush Investment Amount  Peyush Investment Equity  \
# 72                NaN                       NaN                       NaN
# 33                NaN                       NaN                       NaN
# 98                NaN                       NaN                       NaN
# 106               NaN                       NaN                       NaN
# 71                NaN                       NaN                       NaN
# 3                 NaN                       NaN                       NaN
# 113               NaN                       NaN                       NaN
# 68                NaN                       NaN                       NaN
# 45                NaN                       NaN                       NaN
# 18                NaN                       NaN                       NaN
#
#      Peyush Debt Amount  Ghazal Investment Amount  Ghazal Investment Equity  \
# 72                  NaN                       NaN                       NaN
# 33                  NaN                       NaN                       NaN
# 98                  NaN                       NaN                       NaN
# 106                 NaN                       NaN                       NaN
# 71                  NaN                       NaN                       NaN
# 3                   NaN                       NaN                       NaN
# 113                 NaN                       NaN                       NaN
# 68                  NaN                       NaN                       NaN
# 45                  NaN                       NaN                       NaN
# 18                  NaN                       NaN                       NaN
#
#      Ghazal Debt Amount  Number of sharks in deal
# 72                  NaN                       NaN
# 33                  NaN                       NaN
# 98                  NaN                       NaN
# 106                 NaN                       NaN
# 71                  NaN                       NaN
# 3                   NaN                       1.0
# 113                 NaN                       NaN
# 68                  NaN                       NaN
# 45                  NaN                       NaN
# 18                  NaN                       2.0

# %%
shark_tank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 44 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Season Number              117 non-null    int64
#  1   Episode Number             117 non-null    int64
#  2   Episode Title              30 non-null     object
#  3   Pitch Number               117 non-null    int64
#  4   Startup Name               117 non-null    object
#  5   Industry                   75 non-null     object
#  6   Business Description       117 non-null    object
#  7   Number of Presenters       34 non-null     float64
#  8   Male Presenter             29 non-null     float64
#  9   Female Presenter           19 non-null     float64
#  10  Yearly Revenue             11 non-null     float64
#  11  Monthly Sales              16 non-null     float64
#  12  Gross Margin               9 non-null      float64
#  13  Original Ask Amount        104 non-null    float64
#  14  Original Ask Equity        104 non-null    float64
#  15  Valuation Requested        107 non-null    object
#  16  Received Offer             75 non-null     float64
#  17  Accepted Offer             69 non-null     float64
#  18  Total Deal Amount          65 non-null     float64
#  19  Total Deal Equity          65 non-null     float64
#  20  Total Deal Debt            8 non-null      float64
#  21  Valuation Offered          65 non-null     float64
#  22  Ashneer Investment Amount  20 non-null     float64
#  23  Ashneer Investment Equity  20 non-null     float64
#  24  Ashneer Debt Amount        0 non-null      float64
#  25  Namita Investment Amount   20 non-null     float64
#  26  Namita Investment Equity   20 non-null     float64
#  27  Namita Debt Amount         0 non-null      float64
#  28  Anupam Investment Amount   20 non-null     float64
#  29  Anupam Investment Equity   20 non-null     float64
#  30  Anupam Debt Amount         0 non-null      float64
#  31  Vineeta Investment Amount  12 non-null     float64
#  32  Vineeta Investment Equity  12 non-null     float64
#  33  Vineeta Debt Amount        1 non-null      float64
#  34  Aman Investment Amount     20 non-null     float64
#  35  Aman Investment Equity     20 non-null     float64
#  36  Aman Debt Amount           0 non-null      float64
#  37  Peyush Investment Amount   8 non-null      float64
#  38  Peyush Investment Equity   8 non-null      float64
#  39  Peyush Debt Amount         0 non-null      float64
#  40  Ghazal Investment Amount   0 non-null      float64
#  41  Ghazal Investment Equity   0 non-null      float64
#  42  Ghazal Debt Amount         0 non-null      float64
#  43  Number of sharks in deal   20 non-null     float64
# dtypes: float64(36), int64(3), object(5)
# memory usage: 40.3+ KB

# %%
shark_tank.describe().T.round(2)
# Out:
#                            count        mean         std     min        25%  \
# Season Number              117.0        1.00        0.00    1.00       1.00
# Episode Number             117.0       18.74       10.07    1.00      10.00
# Pitch Number               117.0       59.00       33.92    1.00      30.00
# Number of Presenters        34.0        2.06        0.89    1.00       1.25
# Male Presenter              29.0        1.55        0.91    1.00       1.00
# Female Presenter            19.0        1.32        0.58    1.00       1.00
# Yearly Revenue              11.0      198.64      341.23    4.00      54.50
# Monthly Sales               16.0  1827512.50  3876419.04  200.00  175000.00
# Gross Margin                 9.0       46.11       24.82    3.00      30.00
# Original Ask Amount        104.0       67.24       45.66    0.00      46.50
# Original Ask Equity        104.0        5.12        3.82    0.25       2.00
# Received Offer              75.0        0.92        0.27    0.00       1.00
# Accepted Offer              69.0        0.94        0.24    0.00       1.00
# Total Deal Amount           65.0       58.95       30.57    0.00      40.00
# Total Deal Equity           65.0       16.13       13.92    1.00       6.00
# Total Deal Debt              8.0       37.62       26.48   20.00      24.25
# Valuation Offered           65.0      854.65     1098.50    0.00     160.00
# Ashneer Investment Amount   20.0       12.50       19.63    0.00       0.00
# Ashneer Investment Equity   20.0        2.32        5.64    0.00       0.00
# Ashneer Debt Amount          0.0         NaN         NaN     NaN        NaN
# Namita Investment Amount    20.0        7.04       14.53    0.00       0.00
# Namita Investment Equity    20.0        1.85        4.65    0.00       0.00
# Namita Debt Amount           0.0         NaN         NaN     NaN        NaN
# Anupam Investment Amount    20.0        7.28       13.59    0.00       0.00
# Anupam Investment Equity    20.0        2.73        5.45    0.00       0.00
# Anupam Debt Amount           0.0         NaN         NaN     NaN        NaN
# Vineeta Investment Amount   12.0       10.21       11.10    0.00       0.00
# Vineeta Investment Equity   12.0        6.32        8.47    0.00       0.00
# Vineeta Debt Amount          1.0       30.00         NaN   30.00      30.00
# Aman Investment Amount      20.0       18.04       21.39    0.00       0.00
# Aman Investment Equity      20.0        2.24        2.51    0.00       0.00
# Aman Debt Amount             0.0         NaN         NaN     NaN        NaN
# Peyush Investment Amount     8.0       10.17       11.03    0.00       0.00
# Peyush Investment Equity     8.0        4.50        5.74    0.00       0.00
# Peyush Debt Amount           0.0         NaN         NaN     NaN        NaN
# Ghazal Investment Amount     0.0         NaN         NaN     NaN        NaN
# Ghazal Investment Equity     0.0         NaN         NaN     NaN        NaN
# Ghazal Debt Amount           0.0         NaN         NaN     NaN        NaN
# Number of sharks in deal    20.0        2.10        0.97    1.00       1.75
#
#                                  50%         75%          max
# Season Number                   1.00        1.00         1.00
# Episode Number                 19.00       27.00        35.00
# Pitch Number                   59.00       88.00       117.00
# Number of Presenters            2.00        2.00         4.00
# Male Presenter                  1.00        2.00         4.00
# Female Presenter                1.00        1.50         3.00
# Yearly Revenue                100.00      122.50      1200.00
# Monthly Sales              575000.00  2015000.00  16000000.00
# Gross Margin                   50.00       70.00        75.00
# Original Ask Amount            50.00       80.00       300.00
# Original Ask Equity             5.00        7.50        25.00
# Received Offer                  1.00        1.00         1.00
# Accepted Offer                  1.00        1.00         1.00
# Total Deal Amount              50.00       75.00       150.00
# Total Deal Equity              15.00       21.00        75.00
# Total Deal Debt                27.50       35.00        99.00
# Valuation Offered             500.00     1000.00      6667.00
# Ashneer Investment Amount       0.00       21.25        70.00
# Ashneer Investment Equity       0.00        2.19        25.00
# Ashneer Debt Amount              NaN         NaN          NaN
# Namita Investment Amount        0.00        2.08        50.00
# Namita Investment Equity        0.00        0.75        20.00
# Namita Debt Amount               NaN         NaN          NaN
# Anupam Investment Amount        0.00       10.62        50.00
# Anupam Investment Equity        0.00        1.31        16.66
# Anupam Debt Amount               NaN         NaN          NaN
# Vineeta Investment Amount       6.25       20.00        25.00
# Vineeta Investment Equity       1.50       13.12        25.00
# Vineeta Debt Amount            30.00       30.00        30.00
# Aman Investment Amount         10.00       25.00        75.00
# Aman Investment Equity          1.12        4.06         6.66
# Aman Debt Amount                 NaN         NaN          NaN
# Peyush Investment Amount        9.16       13.75        28.00
# Peyush Investment Equity        3.00        6.66        16.66
# Peyush Debt Amount               NaN         NaN          NaN
# Ghazal Investment Amount         NaN         NaN          NaN
# Ghazal Investment Equity         NaN         NaN          NaN
# Ghazal Debt Amount               NaN         NaN          NaN
# Number of sharks in deal        2.00        2.25         5.00

# %%
# Unique values in each column
for col in shark_tank.columns:
    print("Number of unique values in", col, "-", shark_tank[col].nunique())
# Out:
# Number of unique values in Season Number - 1
# Number of unique values in Episode Number - 35
# Number of unique values in Episode Title - 10
# Number of unique values in Pitch Number - 117
# Number of unique values in Startup Name - 117
# Number of unique values in Industry - 14
# Number of unique values in Business Description - 117
# Number of unique values in Number of Presenters - 4
# Number of unique values in Male Presenter - 4
# Number of unique values in Female Presenter - 3
# Number of unique values in Yearly Revenue - 11
# Number of unique values in Monthly Sales - 16
# Number of unique values in Gross Margin - 8
# Number of unique values in Original Ask Amount - 23
# Number of unique values in Original Ask Equity - 16
# Number of unique values in Valuation Requested - 45
# Number of unique values in Received Offer - 2
# Number of unique values in Accepted Offer - 2
# Number of unique values in Total Deal Amount - 20
# Number of unique values in Total Deal Equity - 27
# Number of unique values in Total Deal Debt - 6
# Number of unique values in Valuation Offered - 38
# Number of unique values in Ashneer Investment Amount - 7
# Number of unique values in Ashneer Investment Equity - 9
# Number of unique values in Ashneer Debt Amount - 0
# Number of unique values in Namita Investment Amount - 6
# Number of unique values in Namita Investment Equity - 6
# Number of unique values in Namita Debt Amount - 0
# Number of unique values in Anupam Investment Amount - 7
# Number of unique values in Anupam Investment Equity - 7
# Number of unique values in Anupam Debt Amount - 0
# Number of unique values in Vineeta Investment Amount - 4
# Number of unique values in Vineeta Investment Equity - 6
# Number of unique values in Vineeta Debt Amount - 1
# Number of unique values in Aman Investment Amount - 8
# Number of unique values in Aman Investment Equity - 12
# Number of unique values in Aman Debt Amount - 0
# Number of unique values in Peyush Investment Amount - 5
# Number of unique values in Peyush Investment Equity - 5
# Number of unique values in Peyush Debt Amount - 0
# Number of unique values in Ghazal Investment Amount - 0
# Number of unique values in Ghazal Investment Equity - 0
# Number of unique values in Ghazal Debt Amount - 0
# Number of unique values in Number of sharks in deal - 4

# %% [markdown]
# ## One season of Shark Tank India was broadcasted in SonyLiv OTT
# ### In 35 episodes, there were 117 pitches

# %%
print(shark_tank['Season Number'].max(), "season \n")
print(shark_tank['Episode Number'].max(), "episodes \n")
print(shark_tank['Pitch Number'].max(), "startup companies came pitching \n")
# Out:
# 1 season
#
# 35 episodes
#
# 117 startup companies came pitching

# %%
# Types of industries, came for pitching
print(shark_tank['Industry'].value_counts(), "\n")

fig = plt.figure(figsize=(20, 4))
ax = sns.countplot(x='Industry', data=shark_tank, order=shark_tank['Industry'].value_counts().index)
ax.set_title('Shark Tank India')
for t in ax.patches:
    if (np.isnan(float(t.get_height()))):
        ax.annotate(0, (t.get_x(), 0))
    else:
        ax.annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))
# Out:
# Food                   31
# Beauty/Fashion         11
# Education               7
# Technology              5
# Electrical Vehicles     4
# Medical                 3
# Animal/Pets             3
# Hardware                3
# Manufacturing           2
# Wearables               2
# Tourism                 1
# Services                1
# Apparels                1
# Sports                  1
# Name: Industry, dtype: int64

# %%
print("Total presenters", int(shark_tank['Number of Presenters'].sum()), "\n")

print("Total male presenters", int(shark_tank['Male Presenter'].sum()), "\n")
print(shark_tank['Male Presenter'].value_counts(), "\n")

print("Total female presenters", int(shark_tank['Female Presenter'].sum()), "\n")
print(shark_tank['Female Presenter'].value_counts(), "\n")
# Out:
# Total presenters 70
#
# Total male presenters 45
#
# 1.0    19
# 2.0     6
# 3.0     2
# 4.0     2
# Name: Male Presenter, dtype: int64
#
# Total female presenters 25
#
# 1.0    14
# 2.0     4
# 3.0     1
# Name: Female Presenter, dtype: int64

# %%
# Offers received
print(shark_tank['Received Offer'].value_counts(), "\n")
print(round(shark_tank['Received Offer'].value_counts(normalize=True)*100).astype(str).str.replace('.0', '%'), "\n")
sns.countplot(x='Received Offer', data=shark_tank, palette="ch:.45")
# Out:
# 1.0    69
# 0.0     6
# Name: Received Offer, dtype: int64
#
# 1.0    92%
# 0.0     8%
# Name: Received Offer, dtype: object
# <AxesSubplot:xlabel='Received Offer', ylabel='count'>

# %%
# Offers accepted
print(shark_tank['Accepted Offer'].value_counts(), "\n")
print(round(shark_tank['Accepted Offer'].value_counts(normalize=True)*100).astype(str).str.replace('.0', '%'), "\n")
sns.countplot(x='Accepted Offer', data=shark_tank, palette="ch:.45")
# Out:
# 1.0    65
# 0.0     4
# Name: Accepted Offer, dtype: int64
#
# 1.0    94%
# 0.0     6%
# Name: Accepted Offer, dtype: object
# <AxesSubplot:xlabel='Accepted Offer', ylabel='count'>

# %%
# Sum of investment amount asked by all starup companies, in Shark Tank, in India
print(format_currency(shark_tank['Original Ask Amount'].sum()/100, 'INR', locale='en_IN').replace(".00", ""),"crores")
# Out:
# ₹69.93 crores

# %%
# Sum of investment equity amount offered by all sharks, in Shark Tank, in India
print(format_currency(shark_tank['Total Deal Amount'].sum()/100, 'INR', locale='en_IN').replace(".00", ""),"crores")
# Out:
# ₹38.32 crores

# %%
# Sum of investment debt amount offered by all sharks, in Shark Tank, in India
print(format_currency(shark_tank['Total Deal Debt'].sum()/100, 'INR', locale='en_IN').replace(".00", ""),"crores")
# Out:
# ₹3.01 crores

# %%
# Top 15 investments, as per total deal amount
shark_tank.groupby('Startup Name')['Total Deal Amount'].max().nlargest(15)
# Out:
# Startup Name
# Aas Vidyalaya          150.0
# Annie                  105.0
# Get a Whey             100.0
# Hammer Lifestyle       100.0
# Humpy A2               100.0
# IN A CAN               100.0
# Insurance Samadhan     100.0
# Proxgy                 100.0
# Raising Superstars     100.0
# Revamp Moto            100.0
# Skippi Ice Pops        100.0
# Sunfox Technologies    100.0
# The Renal Project      100.0
# The Yarn Bazaar        100.0
# Kabaddi Adda            80.0
# Name: Total Deal Amount, dtype: float64

# %%
# Top 10 investments, as per total equity amount
shark_tank.groupby('Startup Name')['Total Deal Equity'].max().nlargest(10)
# Out:
# Startup Name
# Sid 07 Designs              75.00
# Booz Scooters               50.00
# Isak Fragrances             50.00
# Hammer Lifestyle            40.00
# KG Agrotech                 40.00
# The Sass Bar                35.00
# Vivalyf Innovations         33.33
# Gold Safe Solutions Ind.    30.00
# Heart up my Sleeves         30.00
# Jain Shikanji               30.00
# Name: Total Deal Equity, dtype: float64

# %%
# Top 5 investments, as per total debt amount
shark_tank.groupby('Startup Name')['Total Deal Debt'].max().nlargest(5)
# Out:
# Startup Name
# Otua            99.0
# Namhya Foods    50.0
# Bamboo India    30.0
# NOCD            30.0
# PNT             25.0
# Name: Total Deal Debt, dtype: float64

# %%
# Ashneer
print("Investment amount by Ashneer", round(shark_tank['Ashneer Investment Amount'].sum()/100, 2), "crores")
print("Equity received by Ashneer", round(shark_tank['Ashneer Investment Equity'].sum(), 2), "%")
print("Debt/loan amount by Ashneer", round(shark_tank['Ashneer Debt Amount'].sum()/100, 2), "crores\n")

print(shark_tank.loc[shark_tank['Ashneer Investment Amount']>0][["Startup Name","Industry","Ashneer Investment Amount"]])

print("\nAshneer industry wise investments\n")
print(shark_tank[shark_tank['Ashneer Investment Amount']>0].groupby('Industry')['Industry'].value_counts().sort_values(ascending=False))
# Out:
# Investment amount by Ashneer 2.5 crores
# Equity received by Ashneer 46.33 %
# Debt/loan amount by Ashneer 0.0 crores
#
#           Startup Name             Industry  Ashneer Investment Amount
# 0       BluePine Foods                 Food                       25.0
# 1        Booz Scooters  Electrical Vehicles                       20.0
# 3           Tagz Foods                 Food                       70.0
# 15     Skippi Ice Pops                 Food                       20.0
# 18  Raising Superstars            Education                       50.0
# 21        Beyond Snack                 Food                       25.0
# 23       Motion Breeze  Electrical Vehicles                       30.0
# 29           EventBeep            Education                       10.0
#
# Ashneer industry wise investments
#
# Industry             Industry
# Food                 Food                   4
# Education            Education              2
# Electrical Vehicles  Electrical Vehicles    2
# Name: Industry, dtype: int64

# %%
# Namita
print("Investment amount by Namita", round(shark_tank['Namita Investment Amount'].sum()/100, 2), "crores")
print("Equity received by Namita", round(shark_tank['Namita Investment Equity'].sum(), 2), "%")
print("Debt/loan amount by Namita", round(shark_tank['Namita Debt Amount'].sum()/100, 2), "crores\n")

print(shark_tank.loc[shark_tank['Namita Investment Amount']>0][["Startup Name","Industry","Namita Investment Amount"]])

print("\n Namita industry wise investments\n")
print(shark_tank[shark_tank['Namita Investment Amount']>0].groupby('Industry')['Industry'].value_counts().sort_values(ascending=False))
# Out:
# Investment amount by Namita 1.41 crores
# Equity received by Namita 36.91 %
# Debt/loan amount by Namita 0.0 crores
#
#        Startup Name        Industry  Namita Investment Amount
# 11           Bummer  Beauty/Fashion                     37.50
# 15  Skippi Ice Pops            Food                     20.00
# 16     Menstrupedia       Education                     50.00
# 24            Altor   Manufacturing                     25.00
# 27          Nuutjob  Beauty/Fashion                      8.33
#
#  Namita industry wise investments
#
# Industry        Industry
# Beauty/Fashion  Beauty/Fashion    2
# Education       Education         1
# Food            Food              1
# Manufacturing   Manufacturing     1
# Name: Industry, dtype: int64

# %%
# Anupam
print("Investment amount by Anupam", round(shark_tank['Anupam Investment Amount'].sum()/100, 2), "crores")
print("Equity received by Anupam", round(shark_tank['Anupam Investment Equity'].sum(), 2), "%")
print("Debt/loan amount by Anupam", round(shark_tank['Anupam Debt Amount'].sum()/100, 2), "crores\n")

print(shark_tank.loc[shark_tank['Anupam Investment Amount']>0][["Startup Name","Industry","Anupam Investment Amount"]])

print("\n Anupam industry wise investments\n")
print(shark_tank[shark_tank['Anupam Investment Amount']>0].groupby('Industry')['Industry'].value_counts().sort_values(ascending=False))
# Out:
# Investment amount by Anupam 1.46 crores
# Equity received by Anupam 54.57 %
# Debt/loan amount by Anupam 0.0 crores
#
#            Startup Name             Industry  Anupam Investment Amount
# 2   Heart up my Sleeves       Beauty/Fashion                      12.5
# 9                Cos IQ       Beauty/Fashion                      25.0
# 12          Revamp Moto  Electrical Vehicles                      50.0
# 15      Skippi Ice Pops                 Food                      20.0
# 22  Vivalyf Innovations              Medical                      28.0
# 28             Meatyour                 Food                      10.0
#
#  Anupam industry wise investments
#
# Industry             Industry
# Beauty/Fashion       Beauty/Fashion         2
# Food                 Food                   2
# Electrical Vehicles  Electrical Vehicles    1
# Medical              Medical                1
# Name: Industry, dtype: int64

# %%
# Vineeta
print("Investment amount by Vineeta", round(shark_tank['Vineeta Investment Amount'].sum()/100, 2), "crores")
print("Equity received by Vineeta", round(shark_tank['Vineeta Investment Equity'].sum(), 2), "%")
print("Debt/loan amount by Vineeta", round(shark_tank['Vineeta Debt Amount'].sum()/100, 2), "crores\n")

print(shark_tank.loc[shark_tank['Vineeta Investment Amount']>0][["Startup Name","Industry","Vineeta Investment Amount"]])

print("\n Vineeta industry wise investments\n")
print(shark_tank[shark_tank['Vineeta Investment Amount']>0].groupby('Industry')['Industry'].value_counts().sort_values(ascending=False))
# Out:
# Investment amount by Vineeta 1.23 crores
# Equity received by Vineeta 75.83 %
# Debt/loan amount by Vineeta 0.3 crores
#
#            Startup Name             Industry  Vineeta Investment Amount
# 0        BluePine Foods                 Food                       25.0
# 1         Booz Scooters  Electrical Vehicles                       20.0
# 2   Heart up my Sleeves       Beauty/Fashion                       12.5
# 8                  NOCD                 Food                       20.0
# 9                Cos IQ       Beauty/Fashion                       25.0
# 15      Skippi Ice Pops                 Food                       20.0
#
#  Vineeta industry wise investments
#
# Industry             Industry
# Food                 Food                   3
# Beauty/Fashion       Beauty/Fashion         2
# Electrical Vehicles  Electrical Vehicles    1
# Name: Industry, dtype: int64

# %%
# Aman
print("Investment amount by Aman", round(shark_tank['Aman Investment Amount'].sum()/100, 2), "crores")
print("Equity received by Aman", round(shark_tank['Aman Investment Equity'].sum(), 2), "%")
print("Debt/loan amount by Aman", round(shark_tank['Aman Debt Amount'].sum()/100, 2), "crores\n")

print(shark_tank.loc[shark_tank['Aman Investment Amount']>0][["Startup Name","Industry","Aman Investment Amount"]])

print("\n Aman industry wise investments\n")
print(shark_tank[shark_tank['Aman Investment Amount']>0].groupby('Industry')['Industry'].value_counts().sort_values(ascending=False))
# Out:
# Investment amount by Aman 3.61 crores
# Equity received by Aman 44.9 %
# Debt/loan amount by Aman 0.0 crores
#
#           Startup Name             Industry  Aman Investment Amount
# 0       BluePine Foods                 Food                   25.00
# 7            Peeschute       Beauty/Fashion                   75.00
# 11              Bummer       Beauty/Fashion                   37.50
# 12         Revamp Moto  Electrical Vehicles                   50.00
# 15     Skippi Ice Pops                 Food                   20.00
# 18  Raising Superstars            Education                   50.00
# 21        Beyond Snack                 Food                   25.00
# 24               Altor        Manufacturing                   25.00
# 25               Ariro        Manufacturing                   25.00
# 27             Nuutjob       Beauty/Fashion                    8.33
# 28            Meatyour                 Food                   10.00
# 29           EventBeep            Education                   10.00
#
#  Aman industry wise investments
#
# Industry             Industry
# Food                 Food                   4
# Beauty/Fashion       Beauty/Fashion         3
# Education            Education              2
# Manufacturing        Manufacturing          2
# Electrical Vehicles  Electrical Vehicles    1
# Name: Industry, dtype: int64

# %%
# Peyush
print("Investment amount by Peyush", round(shark_tank['Peyush Investment Amount'].sum()/100, 2), "crores")
print("Equity received by Peyush", round(shark_tank['Peyush Investment Equity'].sum(), 2), "%")
print("Debt/loan amount by Peyush", round(shark_tank['Peyush Debt Amount'].sum()/100, 2), "crores\n")

print(shark_tank.loc[shark_tank['Peyush Investment Amount']>0][["Startup Name","Industry","Peyush Investment Amount"]])

print("\n Peyush industry wise investments\n")
print(shark_tank[shark_tank['Peyush Investment Amount']>0].groupby('Industry')['Industry'].value_counts().sort_values(ascending=False))
# Out:
# Investment amount by Peyush 0.81 crores
# Equity received by Peyush 35.98 %
# Debt/loan amount by Peyush 0.0 crores
#
#            Startup Name        Industry  Peyush Investment Amount
# 22  Vivalyf Innovations         Medical                     28.00
# 25                Ariro   Manufacturing                     25.00
# 27              Nuutjob  Beauty/Fashion                      8.33
# 28             Meatyour            Food                     10.00
# 29            EventBeep       Education                     10.00
#
#  Peyush industry wise investments
#
# Industry        Industry
# Beauty/Fashion  Beauty/Fashion    1
# Education       Education         1
# Food            Food              1
# Manufacturing   Manufacturing     1
# Medical         Medical           1
# Name: Industry, dtype: int64

# %%
# Ghazal
print("Investment amount by Ghazal", round(shark_tank['Ghazal Investment Amount'].sum()/100, 2), "crores")
print("Equity received by Ghazal", round(shark_tank['Ghazal Investment Equity'].sum(), 2), "%")
print("Debt/loan amount by Ghazal", round(shark_tank['Ghazal Debt Amount'].sum()/100, 2), "crores\n")

print(shark_tank.loc[shark_tank['Ghazal Investment Amount']>0][["Startup Name","Industry","Ghazal Investment Amount"]])

print("\n Ghazal industry wise investments\n")
print(shark_tank[shark_tank['Ghazal Investment Amount']>0].groupby('Industry')['Industry'].value_counts().sort_values(ascending=False))
# Out:
# Investment amount by Ghazal 0.0 crores
# Equity received by Ghazal 0.0 %
# Debt/loan amount by Ghazal 0.0 crores
#
# Empty DataFrame
# Columns: [Startup Name, Industry, Ghazal Investment Amount]
# Index: []
#
#  Ghazal industry wise investments
#
# Series([], Name: Industry, dtype: int64)

# %%
# Number of sharks in deal
print(shark_tank['Number of sharks in deal'].value_counts(), "\n")

# In percentage
print(round(shark_tank['Number of sharks in deal'].value_counts(normalize=True)*100).astype(str).str.replace('.0', '%'))

sns.countplot(data = shark_tank, x = 'Number of sharks in deal')
# Out:
# 2.0    10
# 1.0     5
# 3.0     4
# 5.0     1
# Name: Number of sharks in deal, dtype: int64
#
# 2.0     %%
# 1.0    25%
# 3.0     %%
# 5.0     5%
# Name: Number of sharks in deal, dtype: object
# <AxesSubplot:xlabel='Number of sharks in deal', ylabel='count'>

# %%
# All sharks deal
print(shark_tank.loc[shark_tank['Number of sharks in deal']==5][["Startup Name","Total Deal Amount","Total Deal Equity","Total Deal Debt"]])
# Out:
#        Startup Name  Total Deal Amount  Total Deal Equity  Total Deal Debt
# 15  Skippi Ice Pops              100.0               15.0              NaN

# %%
shark_tank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 44 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Season Number              117 non-null    int64
#  1   Episode Number             117 non-null    int64
#  2   Episode Title              30 non-null     object
#  3   Pitch Number               117 non-null    int64
#  4   Startup Name               117 non-null    object
#  5   Industry                   75 non-null     object
#  6   Business Description       117 non-null    object
#  7   Number of Presenters       34 non-null     float64
#  8   Male Presenter             29 non-null     float64
#  9   Female Presenter           19 non-null     float64
#  10  Yearly Revenue             11 non-null     float64
#  11  Monthly Sales              16 non-null     float64
#  12  Gross Margin               9 non-null      float64
#  13  Original Ask Amount        104 non-null    float64
#  14  Original Ask Equity        104 non-null    float64
#  15  Valuation Requested        107 non-null    object
#  16  Received Offer             75 non-null     float64
#  17  Accepted Offer             69 non-null     float64
#  18  Total Deal Amount          65 non-null     float64
#  19  Total Deal Equity          65 non-null     float64
#  20  Total Deal Debt            8 non-null      float64
#  21  Valuation Offered          65 non-null     float64
#  22  Ashneer Investment Amount  20 non-null     float64
#  23  Ashneer Investment Equity  20 non-null     float64
#  24  Ashneer Debt Amount        0 non-null      float64
#  25  Namita Investment Amount   20 non-null     float64
#  26  Namita Investment Equity   20 non-null     float64
#  27  Namita Debt Amount         0 non-null      float64
#  28  Anupam Investment Amount   20 non-null     float64
#  29  Anupam Investment Equity   20 non-null     float64
#  30  Anupam Debt Amount         0 non-null      float64
#  31  Vineeta Investment Amount  12 non-null     float64
#  32  Vineeta Investment Equity  12 non-null     float64
#  33  Vineeta Debt Amount        1 non-null      float64
#  34  Aman Investment Amount     20 non-null     float64
#  35  Aman Investment Equity     20 non-null     float64
#  36  Aman Debt Amount           0 non-null      float64
#  37  Peyush Investment Amount   8 non-null      float64
#  38  Peyush Investment Equity   8 non-null      float64
#  39  Peyush Debt Amount         0 non-null      float64
#  40  Ghazal Investment Amount   0 non-null      float64
#  41  Ghazal Investment Equity   0 non-null      float64
#  42  Ghazal Debt Amount         0 non-null      float64
#  43  Number of sharks in deal   20 non-null     float64
# dtypes: float64(36), int64(3), object(5)
# memory usage: 40.3+ KB

# %%
text = " Shark Tank India ".join(cat for cat in shark_tank['Business Description'])
#print(text)
#wordcloud = WordCloud(width = 2000, height = 1500, background_color='skyblue', colormap='Pastel2', collocations=False, random_state=2022).generate(text)
wordcloud = WordCloud(width = 3000, height = 2000, background_color='salmon', colormap='Pastel2', collocations=False, random_state=2022).generate(text)
wordcloud.to_file("Shark_Tank_India.png")

# %% [markdown]
# <img src="./Shark_Tank_India.png">

# %%
print("numpy version: {}". format(np.__version__))
print("pandas version: {}". format(pd.__version__))

import matplotlib
print("matplotlib version: {}". format(matplotlib. __version__))
print("seaborn version: {}". format(sns.__version__))


# numpy version: 1.20.3
# pandas version: 1.3.5
# matplotlib version: 3.5.1
# seaborn version: 0.11.2
# Out:
# numpy version: 1.20.3
# pandas version: 1.3.5
# matplotlib version: 3.5.1
# seaborn version: 0.11.2
