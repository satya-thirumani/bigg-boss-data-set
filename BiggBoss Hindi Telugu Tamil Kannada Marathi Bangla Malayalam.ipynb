# %% [markdown]
# <a href="https://www.kaggle.com/code/thirumani/biggboss-hindi-telugu-tamil-kannada-marathi-bangla?scriptVersionId=101542063" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Bigg Boss Hindi/Kannada/Tamil/Telugu/Malayalam/Marathi/Bangla Dataset and Data Analysis (of Indian Big Brother)
#
# ## Dataset https://www.kaggle.com/thirumani/bigg-boss-india-hindi-telugu-tamil-kannada

# %%
from IPython.display import IFrame
import datetime
print("Notebook was last executed on:", datetime.date.today().strftime("%Y-%b-%d"))
# Out:
# Notebook was last executed on: 2022-Jul-23

# %% [markdown]
# ### Importing Required Python Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 50)

import matplotlib.pyplot as plt
import seaborn as sns
from babel.numbers import format_currency
from wordcloud import WordCloud
import geopandas as gpd

# %% [markdown]
# ### Check and import dataset

# %%
! ls -l /kaggle/input/bigg-boss-india-hindi-telugu-tamil-kannada/Bigg_Boss_India.csv
bigg_boss = pd.read_csv('/kaggle/input/bigg-boss-india-hindi-telugu-tamil-kannada/Bigg_Boss_India.csv', encoding = "ISO-8859-1")

nRow, nCol = bigg_boss.shape
print(f'\nThere are {nRow} rows and {nCol} columns in the dataset')
# Out:
# -rw-r--r-- 1 nobody nogroup 145937 Jul 23 04:30 /kaggle/input/bigg-boss-india-hindi-telugu-tamil-kannada/Bigg_Boss_India.csv
#
# There are 827 rows and 26 columns in the dataset

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
bigg_boss.head(5)
# Out:
#   Language Season Number           Name      Profession       Gender  \
# 0    Hindi             1      Amit Sadh      Soap Actor         Male
# 1    Hindi             1  Anupama Verma           Model       Female
# 2    Hindi             1     Aryan Vaid  Pageant Winner         Male
# 3    Hindi             1  Bobby Darling            LGBT  Transgender
# 4    Hindi             1  Carol Gracias           Model       Female
#
#   Entry Date Elimination Date  Elimination Week Number Wild Card  \
# 0  03-Nov-06              NaN                     10.0        No
# 1  03-Nov-06              NaN                      5.0        No
# 2  03-Nov-06              NaN                      4.0        No
# 3  03-Nov-06              NaN                      1.0        No
# 4  03-Nov-06        26-Jan-07                     12.0        No
#
#    Season Length  Number of Housemates Season Start Date Season End Date  \
# 0             86                    15         03-Nov-06       26-Jan-07
# 1             86                    15         03-Nov-06       26-Jan-07
# 2             86                    15         03-Nov-06       26-Jan-07
# 3             86                    15         03-Nov-06       26-Jan-07
# 4             86                    15         03-Nov-06       26-Jan-07
#
#       Host Name Guest Host Name Prize Money (INR) Broadcasted By  Average TRP  \
# 0  Arshad Warsi             NaN                 0        Sony TV         2.72
# 1  Arshad Warsi             NaN                 0        Sony TV         2.72
# 2  Arshad Warsi             NaN                 0        Sony TV         2.72
# 3  Arshad Warsi             NaN                 0        Sony TV         2.72
# 4  Arshad Warsi             NaN                 0        Sony TV         2.72
#
#                                   Most Viewed States OTT Season  \
# 0  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 1  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 2  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 3  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 4  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
#
#    Number of Evictions Faced  Number of re-entries  \
# 0                        3.0                     0
# 1                        1.0                     0
# 2                        1.0                     0
# 3                        1.0                     0
# 4                        6.0                     0
#
#    Number of times elected as Captain  Social Media Popularity  Finalist  \
# 0                                 0.0                      NaN         0
# 1                                 0.0                      NaN         0
# 2                                 0.0                      NaN         0
# 3                                 0.0                      NaN         0
# 4                                 0.0                      NaN         1
#
#    Winner
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
bigg_boss.tail(10).T
# Out:
#                                                817        818  \
# Language                                 Malayalam  Malayalam
# Season Number                                    4          4
# Name                                Naveen Arakkal    Nimisha
# Profession                              Soap Actor      Model
# Gender                                        Male     Female
# Entry Date                               27-Mar-22  27-Mar-22
# Elimination Date                               NaN        NaN
# Elimination Week Number                        5.0        7.0
# Wild Card                                       No         No
# Season Length                                   98         98
# Number of Housemates                            20         20
# Season Start Date                        27-Mar-22  27-Mar-22
# Season End Date                          03-Jul-22  03-Jul-22
# Host Name                                 Mohanlal   Mohanlal
# Guest Host Name                                NaN        NaN
# Prize Money (INR)                                0          0
# Broadcasted By                             Asianet    Asianet
# Average TRP                                    NaN        NaN
# Most Viewed States                          Kerala     Kerala
# OTT Season                                      No         No
# Number of Evictions Faced                      3.0        3.0
# Number of re-entries                             0          1
# Number of times elected as Captain             1.0        1.0
# Social Media Popularity                        NaN        NaN
# Finalist                                         0          0
# Winner                                           0          0
#
#                                                     819             820  \
# Language                                      Malayalam       Malayalam
# Season Number                                         4               4
# Name                                Robin Radhakrishnan  Ronson Vincent
# Profession                                       Doctor      Soap Actor
# Gender                                             Male            Male
# Entry Date                                    27-Mar-22       27-Mar-22
# Elimination Date                                    NaN             NaN
# Elimination Week Number                            10.0            13.0
# Wild Card                                            No              No
# Season Length                                        98              98
# Number of Housemates                                 20              20
# Season Start Date                             27-Mar-22       27-Mar-22
# Season End Date                               03-Jul-22       03-Jul-22
# Host Name                                      Mohanlal        Mohanlal
# Guest Host Name                                     NaN             NaN
# Prize Money (INR)                                     0               0
# Broadcasted By                                  Asianet         Asianet
# Average TRP                                         NaN             NaN
# Most Viewed States                               Kerala          Kerala
# OTT Season                                           No              No
# Number of Evictions Faced                           7.0             8.0
# Number of re-entries                                  0               0
# Number of times elected as Captain                  0.0             1.0
# Social Media Popularity                             7.0             NaN
# Finalist                                              0               0
# Winner                                                0               0
#
#                                              821               822  \
# Language                               Malayalam         Malayalam
# Season Number                                  4                 4
# Name                                Shalini Nair  Sooraj Thelakkad
# Profession                          Video Jockey             Actor
# Gender                                    Female              Male
# Entry Date                             27-Mar-22         27-Mar-22
# Elimination Date                             NaN               NaN
# Elimination Week Number                      3.0              14.0
# Wild Card                                     No                No
# Season Length                                 98                98
# Number of Housemates                          20                20
# Season Start Date                      27-Mar-22         27-Mar-22
# Season End Date                        03-Jul-22         03-Jul-22
# Host Name                               Mohanlal          Mohanlal
# Guest Host Name                              NaN               NaN
# Prize Money (INR)                              0                 0
# Broadcasted By                           Asianet           Asianet
# Average TRP                                  NaN               NaN
# Most Viewed States                        Kerala            Kerala
# OTT Season                                    No                No
# Number of Evictions Faced                    2.0               5.0
# Number of re-entries                           0                 0
# Number of times elected as Captain           0.0               2.0
# Social Media Popularity                      NaN               NaN
# Finalist                                       0                 1
# Winner                                         0                 0
#
#                                                823                    824  \
# Language                                 Malayalam              Malayalam
# Season Number                                    4                      4
# Name                                Suchithra Nair  Manikandan Thonnakkal
# Profession                            Soap Actress      Social Media Star
# Gender                                      Female                   Male
# Entry Date                               27-Mar-22                    NaN
# Elimination Date                               NaN                    NaN
# Elimination Week Number                        9.0                    4.0
# Wild Card                                       No                    Yes
# Season Length                                   98                     98
# Number of Housemates                            20                     20
# Season Start Date                        27-Mar-22              27-Mar-22
# Season End Date                          03-Jul-22              03-Jul-22
# Host Name                                 Mohanlal               Mohanlal
# Guest Host Name                                NaN                    NaN
# Prize Money (INR)                                0                      0
# Broadcasted By                             Asianet                Asianet
# Average TRP                                    NaN                    NaN
# Most Viewed States                          Kerala                 Kerala
# OTT Season                                      No                     No
# Number of Evictions Faced                      2.0                    0.0
# Number of re-entries                             0                      0
# Number of times elected as Captain             0.0                    0.0
# Social Media Popularity                        NaN                    NaN
# Finalist                                         0                      0
# Winner                                           0                      0
#
#                                                   825                826
# Language                                    Malayalam          Malayalam
# Season Number                                       4                  4
# Name                                      Riyas Salim       Vinay Madhav
# Profession                          Social Media Star  Social Media Star
# Gender                                           Male               Male
# Entry Date                                        NaN                NaN
# Elimination Date                                  NaN                NaN
# Elimination Week Number                          14.0               12.0
# Wild Card                                         Yes                Yes
# Season Length                                      98                 98
# Number of Housemates                               20                 20
# Season Start Date                           27-Mar-22          27-Mar-22
# Season End Date                             03-Jul-22          03-Jul-22
# Host Name                                    Mohanlal           Mohanlal
# Guest Host Name                                   NaN                NaN
# Prize Money (INR)                                   0                  0
# Broadcasted By                                Asianet            Asianet
# Average TRP                                       NaN                NaN
# Most Viewed States                             Kerala             Kerala
# OTT Season                                         No                 No
# Number of Evictions Faced                         4.0                5.0
# Number of re-entries                                0                  0
# Number of times elected as Captain                1.0                0.0
# Social Media Popularity                           7.0                NaN
# Finalist                                            1                  0
# Winner                                              0                  0

# %%
bigg_boss.sample(10)
# Out:
#       Language Season Number               Name         Profession  Gender  \
# 760  Malayalam             1  Sabumon Abdusamad          TV Anchor    Male
# 581      Tamil             2  Mahat Raghavendra              Actor    Male
# 132      Hindi             8         Upen Patel              Model    Male
# 553     Telugu      Non-Stop              Shiva  Social Media Star    Male
# 5        Hindi             1    Deepak Parashar              Actor    Male
# 281      Hindi            15        Afsana Khan             Singer  Female
# 23       Hindi             2   Rahul Mahajan            Politician    Male
# 124      Hindi             8   Natasa Stankovic              Model  Female
# 21       Hindi             2   Monica Bedi                 Actress  Female
# 327    Kannada             2        Mayur Patel              Actor    Male
#
#     Entry Date Elimination Date  Elimination Week Number Wild Card  \
# 760  24-Jun-18              NaN                      NaN        No
# 581  17-Jun-18              NaN                     10.0        No
# 132  21-Sep-14        03-Jan-15                     15.0        No
# 553  26-Feb-22              NaN                     12.0        No
# 5    03-Nov-06              NaN                      2.0        No
# 281  02-Oct-21              NaN                      6.0        No
# 23   17-Aug-08              NaN                      NaN        No
# 124  21-Sep-14              NaN                      4.0        No
# 21   17-Aug-08              NaN                     13.0        No
# 327  29-Jun-14              NaN                      6.0        No
#
#      Season Length  Number of Housemates Season Start Date Season End Date  \
# 760             98                    18         24-Jun-18       30-Sep-18
# 581            105                    17         17-Jun-18       30-Sep-18
# 132            105                    19         21-Sep-14       03-Jan-15
# 553             84                    18         26-Feb-22       21-May-22
# 5               86                    15         03-Nov-06       26-Jan-07
# 281            121                    24         02-Oct-21       30-Jan-22
# 23              98                    15         17-Aug-08       22-Nov-08
# 124            105                    19         21-Sep-14       03-Jan-15
# 21              98                    15         17-Aug-08       22-Nov-08
# 327             98                    15         29-Jun-14        5-Oct-14
#
#          Host Name Guest Host Name Prize Money (INR)   Broadcasted By  \
# 760       Mohanlal             NaN       1,00,00,000          Asianet
# 581   Kamal Haasan             NaN                 0       Star Vijay
# 132    Salman Khan      Farah Khan                 0           Colors
# 553      Nagarjuna             NaN                 0  Disney+ Hotstar
# 5     Arshad Warsi             NaN                 0          Sony TV
# 281    Salman Khan             NaN                 0           Colors
# 23   Shilpa Shetty             NaN                 0           Colors
# 124    Salman Khan      Farah Khan                 0           Colors
# 21   Shilpa Shetty             NaN                 0           Colors
# 327         Sudeep             NaN                 0          Suvarna
#
#      Average TRP                                 Most Viewed States  \
# 760        10.33                                             Kerala
# 581         8.20                                         Tamil Nadu
# 132         3.77  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...
# 553          NaN                          Telangana, Andhra Pradesh
# 5           2.72  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...
# 281          NaN  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...
# 23          2.89  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...
# 124         3.77  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...
# 21          2.89  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...
# 327          NaN                                          Karnataka
#
#     OTT Season  Number of Evictions Faced  Number of re-entries  \
# 760         No                        5.0                     0
# 581         No                        3.0                     0
# 132         No                        4.0                     0
# 553        Yes                       10.0                     0
# 5           No                        1.0                     0
# 281         No                        2.0                     0
# 23          No                        4.0                     0
# 124         No                        2.0                     0
# 21          No                        2.0                     1
# 327         No                        2.0                     0
#
#      Number of times elected as Captain  Social Media Popularity  Finalist  \
# 760                                 1.0                      9.0         1
# 581                                 1.0                      NaN         0
# 132                                 1.0                      NaN         0
# 553                                 1.0                      8.0         1
# 5                                   0.0                      NaN         0
# 281                                 0.0                      NaN         0
# 23                                  0.0                      NaN         0
# 124                                 0.0                      NaN         0
# 21                                  0.0                      NaN         0
# 327                                 0.0                      NaN         0
#
#      Winner
# 760       1
# 581       0
# 132       0
# 553       0
# 5         0
# 281       0
# 23        0
# 124       0
# 21        0
# 327       0

# %%
bigg_boss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Language                            827 non-null    object
#  1   Season Number                       827 non-null    object
#  2   Name                                827 non-null    object
#  3   Profession                          827 non-null    object
#  4   Gender                              827 non-null    object
#  5   Entry Date                          703 non-null    object
#  6   Elimination Date                    152 non-null    object
#  7   Elimination Week Number             704 non-null    float64
#  8   Wild Card                           827 non-null    object
#  9   Season Length                       827 non-null    int64
#  10  Number of Housemates                827 non-null    int64
#  11  Season Start Date                   827 non-null    object
#  12  Season End Date                     827 non-null    object
#  13  Host Name                           827 non-null    object
#  14  Guest Host Name                     126 non-null    object
#  15  Prize Money (INR)                   827 non-null    object
#  16  Broadcasted By                      827 non-null    object
#  17  Average TRP                         531 non-null    float64
#  18  Most Viewed States                  827 non-null    object
#  19  OTT Season                          827 non-null    object
#  20  Number of Evictions Faced           809 non-null    float64
#  21  Number of re-entries                827 non-null    int64
#  22  Number of times elected as Captain  788 non-null    float64
#  23  Social Media Popularity             134 non-null    float64
#  24  Finalist                            827 non-null    int64
#  25  Winner                              827 non-null    int64
# dtypes: float64(5), int64(5), object(16)
# memory usage: 168.1+ KB

# %%
bigg_boss.describe().T.round(2).style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_03591_row0_col0 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_03591_row0_col1, #T_03591_row0_col5 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_03591_row0_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_03591_row0_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_03591_row0_col4 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_03591_row0_col6, #T_03591_row0_col7, #T_03591_row3_col7 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_03591_row1_col0, #T_03591_row1_col1, #T_03591_row1_col2, #T_03591_row1_col3, #T_03591_row1_col4, #T_03591_row1_col5, #T_03591_row1_col6, #T_03591_row1_col7, #T_03591_row2_col0, #T_03591_row5_col0, #T_03591_row8_col0, #T_03591_row9_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T
>24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_03591_level0_row3" class="row_heading level0 row3" >Average TRP</th>
#       <td id="T_03591_row3_col0" class="data row3 col0" >531.000000</td>
#       <td id="T_03591_row3_col1" class="data row3 col1" >8.710000</td>
#       <td id="T_03591_row3_col2" class="data row3 col2" >5.550000</td>
#       <td id="T_03591_row3_col3" class="data row3 col3" >2.720000</td>
#       <td id="T_03591_row3_col4" class="data row3 col4" >3.810000</td>
#       <td id="T_03591_row3_col5" class="data row3 col5" >7.640000</td>
#       <td id="T_03591_row3_col6" class="data row3 col6" >12.400000</td>
#       <td id="T_03591_row3_col7" class="data row3 col7" >20.100000</td>
#     </tr>
#     <tr>
#       <th id="T_03591_level0_row4" class="row_heading level0 row4" >Number of Evictions Faced</th>
#       <td id="T_03591_row4_col0" class="data row4 col0" >809.000000</td>
#       <td id="T_03591_row4_col1" class="data row4 col1" >4.230000</td>
#       <td id="T_03591_row4_col2" class="data row4 col2" >2.970000</td>
#       <td id="T_03591_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_03591_row4_col4" class="data row4 col4" >2.000000</td>
#       <td id="T_03591_row4_col5" class="data row4 col5" >4.000000</td>
#       <td id="T_03591_row4_col6" class="data row4 col6" >6.000000</td>
#       <td id="T_03591_row4_col7" class="data row4 col7" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_03591_level0_row5" class="row_heading level0 row5" >Number of re-entries</th>
#       <td id="T_03591_row5_col0" class="data row5 col0" >827.000000</td>
#       <td id="T_03591_row5_col1" class="data row5 col1" >0.080000</td>
#       <td id="T_03591_row5_col2" class="data row5 col2" >0.300000</td>
#       <td id="T_03591_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_03591_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_03591_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_03591_row5_col6" class="data row5 col6" >0.000000</td>

# %%
bigg_boss['Season Start Date'] = pd.to_datetime(bigg_boss['Season Start Date'])
bigg_boss['Season End Date'] = pd.to_datetime(bigg_boss['Season End Date'])
bigg_boss['Entry Date'] = pd.to_datetime(bigg_boss['Entry Date'])
bigg_boss['Elimination Date'] = pd.to_datetime(bigg_boss['Elimination Date'])

# %%
bigg_boss['Finalist'] = bigg_boss['Finalist'].astype(pd.Int32Dtype())
bigg_boss['Elimination Week Number'] = bigg_boss['Elimination Week Number'].astype(pd.Int32Dtype())
bigg_boss['Number of Evictions Faced'] = bigg_boss['Number of Evictions Faced'].astype(pd.Int32Dtype())
bigg_boss['Number of re-entries'] = bigg_boss['Number of re-entries'].astype(pd.Int32Dtype())
bigg_boss['Number of times elected as Captain'] = bigg_boss['Number of times elected as Captain'].astype(pd.Int32Dtype())
bigg_boss['Social Media Popularity'] = bigg_boss['Social Media Popularity'].astype(pd.Int32Dtype())

bigg_boss['Prize Money (INR)'] = bigg_boss['Prize Money (INR)'].str.replace(',','')
bigg_boss['Prize Money (INR)'] = pd.to_numeric(bigg_boss['Prize Money (INR)'])

bigg_boss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Language                            827 non-null    object
#  1   Season Number                       827 non-null    object
#  2   Name                                827 non-null    object
#  3   Profession                          827 non-null    object
#  4   Gender                              827 non-null    object
#  5   Entry Date                          703 non-null    datetime64[ns]
#  6   Elimination Date                    152 non-null    datetime64[ns]
#  7   Elimination Week Number             704 non-null    Int32
#  8   Wild Card                           827 non-null    object
#  9   Season Length                       827 non-null    int64
#  10  Number of Housemates                827 non-null    int64
#  11  Season Start Date                   827 non-null    datetime64[ns]
#  12  Season End Date                     827 non-null    datetime64[ns]
#  13  Host Name                           827 non-null    object
#  14  Guest Host Name                     126 non-null    object
#  15  Prize Money (INR)                   827 non-null    int64
#  16  Broadcasted By                      827 non-null    object
#  17  Average TRP                         531 non-null    float64
#  18  Most Viewed States                  827 non-null    object
#  19  OTT Season                          827 non-null    object
#  20  Number of Evictions Faced           809 non-null    Int32
#  21  Number of re-entries                827 non-null    Int32
#  22  Number of times elected as Captain  788 non-null    Int32
#  23  Social Media Popularity             134 non-null    Int32
#  24  Finalist                            827 non-null    Int32
#  25  Winner                              827 non-null    int64
# dtypes: Int32(6), datetime64[ns](4), float64(1), int64(4), object(11)
# memory usage: 153.6+ KB

# %%
# Unique values in each column
for col in bigg_boss.columns:
    print("Number of unique values in", col, "-", bigg_boss[col].nunique())
# Out:
# Number of unique values in Language - 7
# Number of unique values in Season Number - 19
# Number of unique values in Name - 781
# Number of unique values in Profession - 82
# Number of unique values in Gender - 4
# Number of unique values in Entry Date - 55
# Number of unique values in Elimination Date - 90
# Number of unique values in Elimination Week Number - 20
# Number of unique values in Wild Card - 2
# Number of unique values in Season Length - 20
# Number of unique values in Number of Housemates - 11
# Number of unique values in Season Start Date - 46
# Number of unique values in Season End Date - 44
# Number of unique values in Host Name - 14
# Number of unique values in Guest Host Name - 6
# Number of unique values in Prize Money (INR) - 15
# Number of unique values in Broadcasted By - 13
# Number of unique values in Average TRP - 28
# Number of unique values in Most Viewed States - 7
# Number of unique values in OTT Season - 2
# Number of unique values in Number of Evictions Faced - 17
# Number of unique values in Number of re-entries - 4
# Number of unique values in Number of times elected as Captain - 6
# Number of unique values in Social Media Popularity - 8
# Number of unique values in Finalist - 2
# Number of unique values in Winner - 2

# %%
# Number of seasons in all Indian languages
print("Total", bigg_boss.groupby('Language')['Season Number'].nunique().sum(), "seasons broadcasted (in TV & OTT)")
print(bigg_boss['Winner'].sum().astype(int)+1, "seasons completed")
print(bigg_boss.loc[bigg_boss['Winner'].isnull(), :].groupby('Language')['Season Number'].nunique().sum(), "season(s) running")
# Out:
# Total 46 seasons broadcasted (in TV & OTT)
# 46 seasons completed
# 0 season(s) running

# %% [markdown]
# ## Bigg Boss Hindi has many seasons compared to other Indian languages. So, the number of housemates are more in Hindi.

# %%
# Number of seasons in each Indian language
print(bigg_boss.groupby('Language')['Season Number'].nunique().nlargest(10))
# Out:
# Language
# Hindi        17
# Kannada       8
# Tamil         6
# Telugu        6
# Malayalam     4
# Marathi       3
# Bengali       2
# Name: Season Number, dtype: int64

# %%
temp = bigg_boss[["Language","Season Number","Number of Housemates","Most Viewed States"]]
temp.drop_duplicates(inplace=True)
temp = temp.assign(Group=temp["Most Viewed States"].str.split(',')).explode("Group")
temp = temp.set_index('Group')
#temp.sample(20).sort_values(['Language',"Season Number",'Number of Housemates'])

# %%
shp_gdf = gpd.read_file('../input/india-gis-data/India States/Indian_states.shp')
shp_gdf = shp_gdf.set_index('st_nm')
merged = shp_gdf.join(temp)
merged['Number of Housemates'] = merged['Number of Housemates'].fillna(0)

# %%
temp2 = merged.loc['Telangana']
temp2['geometry'] = list(shp_gdf.loc['Andhra Pradesh'].repeat(6))
temp2.rename(index=lambda s: 'Andhra Pradesh', inplace=True)
merged = pd.concat([merged, temp2], axis=0)

for state in ['Bihar', 'NCT of Delhi', 'Haryana', 'Jharkhand', 'Madhya Pradesh', 'Rajasthan', 'Uttarakhand', 'Uttar Pradesh']:
    temp2 = merged.loc['Maharashtra']
    temp2['geometry'] = list(shp_gdf.loc[state].repeat(20))
    temp2.rename(index=lambda s: state, inplace=True)
    merged = pd.concat([merged, temp2], axis=0)

# %%
fig, ax = plt.subplots(1, figsize=(12, 12))
ax.axis('off')
ax.set_title('As per Most Viewed States', fontdict={'fontsize': '15', 'fontweight' : '3'})
fig = merged.plot(column='Number of Housemates', cmap='viridis_r', linewidth=0.8, ax=ax, edgecolor='0.5', legend=True)

# %%
# Total number of Bigg Boss housemates
fig = plt.figure(figsize=(10, 4))
ax = sns.countplot(x='Language', data=bigg_boss, order=bigg_boss['Language'].value_counts().index)
ax.set_title('Bigg Boss Series - Indian Languages', fontsize=14)
plt.xticks(fontsize=16)
plt.xlabel("Language", fontsize=14)
plt.ylabel("Total Housemates", fontsize=16)
for t in ax.patches:
    if (np.isnan(float(t.get_height()))):
        ax.annotate(0, (t.get_x(), 0))
    else:
        ax.annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))

# %% [markdown]
# ## In Bigg Boss India seasons, most of the housemates entered in first day/week

# %%
# Number of normal entries and wild card entries
print(bigg_boss['Wild Card'].value_counts(), "\n")
print(round(bigg_boss['Wild Card'].value_counts(normalize=True)*100).astype(str).str.replace('.0', '%'), "\n")

plt.figure(figsize=(15, 8))
ax1=plt.subplot(221)
bigg_boss['Wild Card'].value_counts().plot(kind='bar',color=["lightblue","pink"],ec="k")
plt.xlabel("Will card entry or not ?", fontsize=14)
plt.xticks(rotation=0, fontsize=16)
plt.setp(ax1.get_yticklabels(), visible=False)

for x,y in enumerate(bigg_boss['Wild Card'].value_counts()):
    plt.annotate(y,(x,y),fontsize=12,color="blue")
    
ax2=plt.subplot(222)
bigg_boss['Wild Card'].value_counts().plot(kind='pie',autopct='%.0f',explode = (0,0.10),colors=["lightblue","pink"],shadow=True)
# Out:
# No     692
# Yes    135
# Name: Wild Card, dtype: int64
#
# No     84%
# Yes    16%
# Name: Wild Card, dtype: object
# <AxesSubplot:ylabel='Wild Card'>

# %%
# Common people has many professions, so clubbing them into one category
bigg_boss['Profession'] = bigg_boss['Profession'].fillna('UNKNOWN')
bigg_boss.loc[bigg_boss['Profession'].str.contains('Commoner'),'Profession'] = 'Commoner'

# %% [markdown]
# ## Number of film actresses entered into the Bigg Boss houses, are more when compared to other professions

# %%
# Participant's Profession
print(bigg_boss['Profession'].value_counts())
fig = plt.figure(figsize=(20, 6))
sns.countplot(x='Profession', data=bigg_boss, order=bigg_boss['Profession'].value_counts().index)
plt.xticks(fontsize=14, rotation=90)
plt.xlabel("Profession", fontsize=14)
plt.ylabel("Count", fontsize=16)
# Out:
# Actress                  180
# Actor                    133
# Soap Actress              67
# Model                     62
# Singer                    52
# Soap Actor                42
# Commoner                  40
# TV Anchor                 25
# Social Media Star         25
# Reality Show Alumni       22
# Comedian                  19
# Radio Jockey              17
# Choreographer             15
# News Presenter            14
# Sports Person              9
# Film Director              8
# Activist                   8
# Video Jockey               7
# International Star         6
# Politician                 6
# Pageant Winner             6
# Producer                   5
# Dancer                     4
# Swamiji                    4
# LGBT                       4
# Controversial Fame         4
# Musician                   3
# Wrestler                   3
# Businessman                3
# Lyricist                   2
# Journalist                 2
# Doctor                     2
# Folk Artist                2
# Fashion Designer           2
# Stage Actress              2
# Actor & Actress            1
# Magician                   1
# Chef                       1
# Dubbing Artist             1
# International star         1
# Author                     1
# Astrologer                 1
# Gym Trainer                1
# Photograher                1
# Preacher                   1
# Celebrity Hairstylist      1
# Theatre Artist             1
# Film Critic                1
# Numerologist               1
# Cartoonist                 1
# Air Hostess                1
# Film director              1
# Art Director               1
# Political Analyst          1
# Writer                     1
# Lawyer                     1
# Fitness Trainer            1
# Name: Profession, dtype: int64
# Text(0, 0.5, 'Count')

# %%
# Broadcaster
fig = plt.figure(figsize=(20, 5))
ax = sns.countplot(x='Broadcasted By', data=bigg_boss, palette='RdBu', order=bigg_boss['Broadcasted By'].value_counts().index)
ax.set_title('Bigg Boss Series - Indian Broadcaster & Total Number of Housemates', fontsize=14)
plt.xticks(fontsize=13, rotation=45)
plt.xlabel("Broadcasted By", fontsize=14)
plt.ylabel("Count", fontsize=16)
for t in ax.patches:
    if (np.isnan(float(t.get_height()))):
        ax.annotate(0, (t.get_x(), 0))
    else:
        ax.annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))

# %%
fig = plt.figure(figsize=(15, 5))
ax = sns.countplot(bigg_boss['Broadcasted By'].str.split().str.get(0), data=bigg_boss, palette='Set3', order=bigg_boss['Broadcasted By'].str.split().str.get(0).value_counts().index)
ax.set_title('BiggBoss Series - Media House', fontsize=14)
plt.xticks(fontsize=15)
plt.xlabel("Broadcasted By", fontsize=14)
plt.ylabel("Count", fontsize=16)
for t in ax.patches:
    if (np.isnan(float(t.get_height()))):
        ax.annotate(0, (t.get_x(), 0))
    else:
        ax.annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))

# %% [markdown]
# ## Salman Khan hosted most number of seasons (in Bigg Boss Hindi), Sudeep is next on the list

# %%
# Bigg Boss main hosts and number of seasons they hosted
bigg_boss.groupby('Host Name')['Season Number'].nunique().nlargest(25)
# Out:
# Host Name
# Salman Khan            12
# Sudeep                  8
# Kamal Haasan            6
# Mohanlal                4
# Nagarjuna               4
# Mahesh Manjrekar        3
# Mithun Chakraborthy     2
# Amitabh Bachchan        1
# Arshad Warsi            1
# Farah Khan              1
# Jr. NTR                 1
# Karan Johar             1
# Nani                    1
# Shilpa Shetty           1
# Name: Season Number, dtype: int64

# %%
# Temporary or Guest host who hosted the week-end episodes
bigg_boss.groupby('Guest Host Name')['Season Number'].nunique().nlargest(10)
# Out:
# Guest Host Name
# Ramya Krishnan       2
# Farah Khan           1
# Samantha             1
# Sanjay Dutt          1
# Siddhartha Jadhav    1
# Simbu                1
# Name: Season Number, dtype: int64

# %% [markdown]
# ## In all Bigg Boss competitions, in languages and in all seasons, Female contestants are more

# %%
# Housemate's Gender
print(bigg_boss['Gender'].value_counts(), "\n")

# In percentage
print(round(bigg_boss['Gender'].value_counts(normalize=True)*100).astype(str).str.replace('.0', '%'))

sns.countplot(data = bigg_boss, x = 'Gender')
plt.xticks(fontsize=15)
plt.xlabel("Gender", fontsize=16)
plt.ylabel("Count", fontsize=16)
# Out:
# Female         431
# Male           389
# Transgender      6
# Couple           1
# Name: Gender, dtype: int64
#
# Female         52%
# Male           47%
# Transgender     1%
# Couple          0%
# Name: Gender, dtype: object
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Only 6 Transgenders (LGBT) participated in all Indian languages

# %%
# Maximum TRP of Bigg Boss India seasons (Big Brother in India)
print("Maximum TRP", bigg_boss['Average TRP'].max(), "\n")
print(bigg_boss.loc[bigg_boss['Average TRP']==bigg_boss['Average TRP'].max()][["Language","Season Number"]].head(1).to_string(index=False))
# Out:
# Maximum TRP 20.1
#
# Language Season Number
#   Telugu             4

# %%
# Smallest season of Indian Bigg Boss seasons
print("Smallest season", bigg_boss['Season Length'].min(), "days \n")
print(bigg_boss.loc[bigg_boss['Season Length']==bigg_boss['Season Length'].min()][["Language","Season Number"]].head(1).to_string(index=False))
# Out:
# Smallest season 28 days
#
# Language Season Number
#    Hindi     Halla Bol

# %%
# Longest season of Bigg Boss Indian seasons
print("Longest season", bigg_boss['Season Length'].max(), "days \n")
print(bigg_boss.loc[bigg_boss['Season Length']==bigg_boss['Season Length'].max()][["Language","Season Number"]].head(1).to_string(index=False))
# Out:
# Longest season 143 days
#
# Language Season Number
#    Hindi            14

# %% [markdown]
# ## Shark Tank India data set https://www.kaggle.com/thirumani/shark-tank-india

# %%
print("Maximum number of contestants in one season:", bigg_boss['Number of Housemates'].max(), "\n")
print(bigg_boss.loc[bigg_boss['Number of Housemates']==bigg_boss['Number of Housemates'].max()][["Language","Season Number"]].head(1).to_string(index=False))
# Out:
# Maximum number of contestants in one season: 24
#
# Language Season Number
#    Hindi            15

# %%
print("Maximum number of evictions faced in one season:", bigg_boss['Number of Evictions Faced'].max(), "\n")
print("\nTop 3 contestants who faced maximum number of evictions\n")
print(bigg_boss.loc[bigg_boss['Number of Evictions Faced']>=bigg_boss['Number of Evictions Faced'].max()-3][["Language","Season Number","Name","Number of Evictions Faced"]].head(3).sort_values("Number of Evictions Faced",ascending=False).to_string(index=False))
# Out:
# Maximum number of evictions faced in one season: 17
#
#
# Top 3 contestants who faced maximum number of evictions
#
# Language Season Number               Name  Number of Evictions Faced
#    Hindi            14      Rubina Dilaik                         17
#  Kannada             8 Prashanth Sambargi                         15
#    Hindi            14       Rahul Vaidya                         14

# %%
bigg_boss['Season Length in weeks'] = round(bigg_boss['Season Length']/7,0).astype(pd.Int32Dtype())
bigg_boss['Evictions Faced Percentage'] = round(bigg_boss['Number of Evictions Faced']/bigg_boss['Season Length in weeks']*100,0).astype(pd.Int32Dtype())
print("Maximum percentage of evictions faced in one season:", bigg_boss['Evictions Faced Percentage'].max(), "%\n")
print("\nTop 5 contestants who faced maximum percentage of evictions (they were in nominations almost every week)\n")
print(bigg_boss.loc[bigg_boss['Evictions Faced Percentage']>=bigg_boss['Evictions Faced Percentage'].max()-15][["Language","Season Number","Name","Number of Evictions Faced","Season Length in weeks","Evictions Faced Percentage"]].head(5).sort_values("Evictions Faced Percentage",ascending=False).to_string(index=False))
# Out:
# Maximum percentage of evictions faced in one season: 100 %
#
#
# Top 5 contestants who faced maximum percentage of evictions (they were in nominations almost every week)
#
# Language Season Number               Name  Number of Evictions Faced  Season Length in weeks  Evictions Faced Percentage
#    Hindi     Halla Bol      Dimpy Ganguly                          4                       4                         100
#    Tamil      Ultimate      Maria Juliana                         10                      10                         100
#   Telugu      Non-Stop     Mitraaw Sharma                         11                      12                          92
#  Kannada             8 Prashanth Sambargi                         15                      17                          88
#    Hindi            14      Rubina Dilaik                         17                      20                          85

# %%
print("Maximum number of re-entries:", bigg_boss['Number of re-entries'].max(), "\n")
print(bigg_boss.loc[bigg_boss['Number of re-entries']>=bigg_boss['Number of re-entries'].max()-1][["Language","Season Number","Name","Number of re-entries"]].head(5).sort_values("Number of re-entries",ascending=False).to_string(index=False))
# Out:
# Maximum number of re-entries: 3
#
# Language Season Number         Name  Number of re-entries
#    Hindi            14  Vikas Gupta                     3
#   Telugu             1 Mumaith Khan                     2
#   Telugu             2  Nutan Naidu                     2

# %%
print("Maximum number of times elected as captain:", bigg_boss['Number of times elected as Captain'].max(), "\n")
print(bigg_boss.loc[bigg_boss['Number of times elected as Captain']>=bigg_boss['Number of times elected as Captain'].max()-1][["Language","Season Number","Name","Number of times elected as Captain"]].head(6).sort_values("Number of times elected as Captain",ascending=False).to_string(index=False))
# Out:
# Maximum number of times elected as captain: 5
#
#  Language Season Number           Name  Number of times elected as Captain
#     Hindi            12    Surbhi Rana                                   5
#     Hindi             9  Prince Narula                                   4
#     Hindi            10 Manveer Gurjar                                   4
# Malayalam             2  Saju Navodaya                                   4

# %%
# Many contestants entered via wild card, but 24 people managed to go to Finale
print(bigg_boss.loc[(bigg_boss['Wild Card']=='Yes') & (bigg_boss['Finalist']==1), 'Finalist'].value_counts())
bigg_boss.loc[(bigg_boss['Wild Card']=='Yes') & (bigg_boss['Finalist']==1), :]
# Out:
# 1    24
# Name: Finalist, dtype: Int64
#       Language Season Number                      Name           Profession  \
# 44       Hindi             3              Pravesh Rana                Model
# 59       Hindi             4  Dalip Singh Rana (Khali)             Wrestler
# 60       Hindi             4              Dolly Bindra              Actress
# 75       Hindi             5             Amar Upadhyay                Actor
# 76       Hindi             5        Siddharth Bhardwaj  Reality Show Alumni
# 77       Hindi             5          Akashdeep Saigal                Actor
# 96       Hindi             6             Imam Siddique  Reality Show Alumni
# 115      Hindi             7                 Ajaz Khan                Actor
# 133      Hindi             8            Ali Quli Mirza               Singer
# 135      Hindi             8             Dimpy Ganguly            TV Anchor
# 161      Hindi             9             Rishabh Sinha           Soap Actor
# 260      Hindi            14                  Aly Goni                Actor
# 263      Hindi            14              Rakhi Sawant              Actress
# 301      Hindi            15             Rashami Desai         Soap Actress
# 466     Telugu             1                   Navdeep                Actor
# 557     Telugu      Non-Stop              Baba Bhaskar        Choreographer
# 575      Tamil             1             Harish Kalyan                Actor
# 593      Tamil             2             Vijayalakshmi              Actress
# 647      Tamil             5                      Amir        Choreographer
# 664      Tamil      Ultimate             Ramya Pandian              Actress
# 680    Marathi             1          Sharmishtha Raut              Actress
# 699    Marathi             2             Aroh Velankar                Actor
# 765  Malayalam             1             Shiyas Kareem                Actor
# 825  Malayalam             4               Riyas Salim    Social Media Star
#
#      Gender Entry Date Elimination Date  Elimination Week Number Wild Card  \
# 44     Male        NaT              NaT                       12       Yes
# 59     Male        NaT       2011-01-08                       14       Yes
# 60   Female        NaT       2011-01-08                       14       Yes
# 75     Male        NaT       2012-01-07                       14       Yes
# 76     Male        NaT       2012-01-07                       14       Yes
# 77     Male        NaT       2012-01-07                       14       Yes
# 96     Male        NaT       2013-01-12                       14       Yes
# 115    Male        NaT       2013-12-28                       15       Yes
# 133    Male        NaT       2015-01-03                       15       Yes
# 135  Female        NaT       2015-01-03                       15       Yes
# 161    Male        NaT       2016-01-23                       15       Yes
# 260    Male        NaT              NaT                       20       Yes
# 263  Female        NaT              NaT                       20       Yes
# 301  Female        NaT              NaT                       17       Yes
# 466    Male 2017-08-14       2017-09-24                       10       Yes
# 557    Male        NaT              NaT                       12       Yes
# 575    Male        NaT       2017-09-30                       14       Yes
# 593  Female        NaT       2018-09-30                       15       Yes
# 647    Male        NaT              NaT                       15       Yes
# 664  Female        NaT              NaT                     <NA>       Yes
# 680  Female        NaT              NaT                       14       Yes
# 699    Male        NaT              NaT                       14       Yes
# 765    Male        NaT              NaT                       14       Yes
# 825    Male        NaT              NaT                       14       Yes
#
#      Season Length  Number of Housemates Season Start Date Season End Date  \
#
NaN  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...
# 466        15.00                          Telangana, Andhra Pradesh
# 557          NaN                          Telangana, Andhra Pradesh
# 575         7.80                                         Tamil Nadu
# 593         8.20                                         Tamil Nadu
# 647        18.60                                         Tamil Nadu
# 664          NaN                                         Tamil Nadu
# 680          NaN                                        Maharashtra
# 699          NaN                                        Maharashtra
# 765        10.33                                             Kerala
# 825          NaN                                             Kerala
#
#     OTT Season  Number of Evictions Faced  Number of re-entries  \
# 44          No                          4                     0
# 59          No                          2                     0
# 60          No                          4                     0
# 75          No                          7                     0
# 76          No                          5                     0
# 77          No                          5                     0
# 96          No                          6                     1
# 115         No                          7                     0
# 133         No                          6                     0
# 135         No                          5                     0
# 161         No                          9                     0
# 260         No                          9                     1
# 263         No                          5                     0
# 301         No                          2                     0
# 466         No                          3                     0
# 557        Yes                          3                     0
# 575         No                          4                     0
# 593         No                          4                     0
# 647         No                          2                     0
# 664        Yes                          3                     0
# 680         No                          5                     0
# 699         No                          4                     0
# 765         No                          0                     0
# 825         No                          4                     0
#
#      Number of times elected as Captain  Social Media Popularity  Finalist  \
# 44                                    0                     <NA>         1
# 59                                    2                     <NA>         1
# 60                                    1                     <NA>         1
# 75                                    1                     <NA>         1
# 76                                    0                     <NA>         1
# 77                                    1                     <NA>         1
# 96                                    1                     <NA>         1
# 115                                   0                     <NA>         1
# 133                                   1                     <NA>         1
# 135                                   1                     <NA>         1
# 161                                   1                     <NA>         1
# 260                                   1                     <NA>         1
# 263                                   0                     <NA>         1
# 301                                   0                     <NA>         1
# 466                                   1                        9         1
# 557                                   1                        6         1
# 575                                   1                        5         1
# 593                                   0                        6         1
# 647                                   1                        8         1
# 664                                   0                     <NA>         1
# 680                                   0                     <NA>         1
# 699                                   0                     <NA>         1
# 765                                   1                        7         1
# 825                                   1                        7         1
#
#      Winner  Season Length in weeks  Evictions Faced Percentage
# 44        0                      12                          33
# 59        0                      14                          14
# 60        0                      14                          29
# 75        0                      14                          50
# 76        0                      14                          36
# 77        0                      14                          36
# 96        0                      14                          43
# 115       0                      15                          47
# 133       0                      15                          40
# 135       0                      15                          33
# 161       0                      15                          60
# 260       0                      20                          45
# 263       0                      20                          25
# 301       0                      17                          12
# 466       0                      10                          30
# 557       0                      12                          25
# 575       0                      14                          29
# 593       0                      15                          27
# 647       0                      15                          13
# 664       0                      10                          30
# 680       0                      14                          36
# 699       0                      14                          29
# 765       0                      14                           0
# 825       0                      14                          29

# %%
# Number of Wild card entries went to Finale, as per Language
bigg_boss.loc[(bigg_boss['Wild Card']=='Yes') & (bigg_boss['Finalist']==1), 'Language'].value_counts()
# Out:
# Hindi        14
# Tamil         4
# Telugu        2
# Marathi       2
# Malayalam     2
# Name: Language, dtype: int64

# %%
# Persons who participated in more than one season (in same/different languages)
print(bigg_boss.groupby('Name')['Season Number'].nunique().nlargest(43))
bigg_boss[bigg_boss.groupby('Name')['Season Number'].transform('size')>1] [["Name", "Language", "Season Number"]].sort_values(by=['Name','Season Number'], ascending=True)
# Out:
# Name
# Rakhi Sawant               3
# Shamita Shetty             3
# Vikas Gupta                3
# Abhinay Vaddi              2
# Abhirami Venkatachalam     2
# Ajaz Khan                  2
# Akhil Sarthak              2
# Ali Quli Mirza             2
# Anitha Sampath             2
# Ariyana Glory              2
# Arshi Khan                 2
# Ashu Reddy                 2
# Baba Bhaskar               2
# Balaji Murugadoss          2
# Bindu Madhavi              2
# Devoleena Bhattacharjee    2
# Dimpy Ganguly              2
# Gautam Gulati              2
# Hamida Khatoon             2
# Karishma Tanna             2
# Mahek Chahal               2
# Mahesh Vitta               2
# Manu Punjabi               2
# Maria Juliana              2
# Megha Dhade                2
# Mumaith Khan               2
# Nataraj                    2
# Neha Bhasin                2
# Nishant Bhat               2
# Pratik Sehajpal            2
# Pritam Singh               2
# Rahul Mahajan              2
# Ramya Pandian              2
# Raqesh Bapat               2
# Rashami Desai              2
# Sana Khan                  2
# Sarayu                     2
# Snehan                     2
# Suja Varunee               2
# Suruthi Periyasamy         2
# Tejaswi Madivada           2
# Thamarai Selvi             2
# Vanitha Vijayakumar        2
# Name: Season Number, dtype: int64
#                        Name Language Season Number
# 629           Abhinay Vaddi    Tamil             5
# 649           Abhinay Vaddi    Tamil      Ultimate
# 594  Abhirami Venkatachalam    Tamil             3
# 650  Abhirami Venkatachalam    Tamil      Ultimate
# 115               Ajaz Khan    Hindi             7
# ..                      ...      ...           ...
# 608     Vanitha Vijayakumar    Tamil             3
# 662     Vanitha Vijayakumar    Tamil      Ultimate
# 201             Vikas Gupta    Hindi            11
# 245             Vikas Gupta    Hindi            13
# 262             Vikas Gupta    Hindi            14
#
# [89 rows x 3 columns]

# %%
# Persons who participated in more than one language
bigg_boss.groupby('Name')['Language'].nunique().nlargest(2)
# Out:
# Name
# Bindu Madhavi    2
# Megha Dhade      2
# Name: Language, dtype: int64

# %%
# 16 housemates eliminated or walked without facing even single nomination 
print(bigg_boss.loc[(bigg_boss['Number of Evictions Faced']==0), 'Number of Evictions Faced'].value_counts())
bigg_boss.loc[(bigg_boss['Number of Evictions Faced']==0), :]
# Out:
# 0    16
# Name: Number of Evictions Faced, dtype: Int64
#       Language Season Number                      Name          Profession  \
# 12       Hindi             1              Salil Ankola       Sports Person
# 19       Hindi             2          Jade Goody        International Star
# 39       Hindi             3            Shamita Shetty             Actress
# 73       Hindi             5          Sonika Kaliraman            Wrestler
# 152      Hindi             9          Kishwar Merchant        Soap Actress
# 245      Hindi            13               Vikas Gupta            Producer
# 298      Hindi            15              Raqesh Bapat               Actor
# 302      Hindi            15              Rakhi Sawant             Actress
# 337    Kannada             3             Huccha Venkat               Actor
# 388    Kannada             5  Vaishnavi Chandran Menon             Actress
# 449    Kannada             8          Vyjayanthi Adiga             Actress
# 639      Tamil             5         Namitha Marimuthu               Model
# 757  Malayalam             1            Manoj K. Verma         Businessman
# 765  Malayalam             1             Shiyas Kareem               Actor
# 785  Malayalam             2         Pavan Gino Thomas               Model
# 824  Malayalam             4     Manikandan Thonnakkal   Social Media Star
#
#           Gender Entry Date Elimination Date  Elimination Week Number  \
# 12          Male 2006-11-03              NaT                        1
# 19        Female 2008-08-17              NaT                     <NA>
# 39        Female 2009-10-04              NaT                     <NA>
# 73        Female 2011-10-02              NaT                     <NA>
# 152       Female 2015-10-11              NaT                     <NA>
# 245         Male        NaT              NaT                       13
# 298         Male        NaT              NaT                        6
# 302       Female        NaT              NaT                       17
# 337         Male 2015-10-25              NaT                     <NA>
# 388       Female        NaT              NaT                       15
# 449       Female        NaT              NaT                        6
# 502            Nagarjuna           Samantha            2500000
# 536            Nagarjuna                NaN            5000000
# 545            Nagarjuna                NaN            4000000
# 558         Kamal Haasan                NaN            5000000
# 587         Kamal Haasan                NaN            5000000
# 601         Kamal Haasan                NaN            5000000
# 612         Kamal Haasan                NaN            5000000
# 643         Kamal Haasan     Ramya Krishnan            3800000
# 652         Kamal Haasan              Simbu            3500000
# 670     Mahesh Manjrekar                NaN            2500000
# 692     Mahesh Manjrekar                NaN            2500000
# 714     Mahesh Manjrekar  Siddhartha Jadhav            2000000
# 718  Mithun Chakraborthy                NaN            2000000
# 735  Mithun Chakraborthy                NaN            3500000
# 760             Mohanlal                NaN           10000000
# 796             Mohanlal                NaN            7500000
# 813             Mohanlal                NaN            5000000
#
#       Broadcasted By  Average TRP  \
# 8            Sony TV         2.72
# 16            Colors         2.89
# 42            Colors         2.83
# 57            Colors         4.95
# 62            Colors         4.19
# 92            Colors         3.81
# 102           Colors         4.40
# 121           Colors         3.77
# 140           Colors         2.82
# 154           Colors         2.90
# 175           Colors         3.54
# 199           Colors         7.64
# 206           Colors         4.99
# 235           Colors         9.06
# 254           Colors          NaN
# 269             Voot          NaN
# 293           Colors          NaN
# 316      ETV Kannada         4.70
# 321          Suvarna          NaN
# 348   Colors Kannada          NaN
# 362   Colors Kannada          NaN
# 373   Colors Kannada          NaN
# 406   Colors Kannada          NaN
# 426   Colors Kannada          NaN
# 437   Colors Kannada          NaN
# 464         Star Maa        15.00
# 474         Star Maa        15.00
# 493         Star Maa        18.10
# 502         Star Maa        20.10
# 536         Star Maa        18.20
# 545  Disney+ Hotstar          NaN
# 558       Star Vijay         7.80
# 587       Star Vijay         8.20
# 601       Star Vijay         8.80
# 612       Star Vijay        15.60
# 643       Star Vijay        18.60
# 652  Disney+ Hotstar          NaN
# 670   Colors Marathi          NaN
# 692   Colors Marathi          NaN
# 714   Colors Marathi          NaN
# 718       ETV Bangla         2.90
# 735   Colors Bangla          6.50
# 760          Asianet        10.33
# 796          Asianet        12.40
# 813          Asianet          NaN
#
#                                     Most Viewed States OTT Season  \
# 8    Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 16   Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 42   Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 57   Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 62   Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 92   Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 102  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 121  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 140  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 154  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 175  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 199  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 206  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 235  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 254  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 269  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...        Yes
# 293  Maharashtra, Bihar, Delhi, Haryana, Jharkhand,...         No
# 316                                          Karnataka         No
# 321                                          Karnataka         No
# 348                                          Karnataka         No
# 362                                          Karnataka         No
# 373                                          Karnataka         No
# 406                                          Karnataka         No
# 426                                          Karnataka         No
# 437                                          Karnataka         No
# 464                          Telangana, Andhra Pradesh         No
# 474                          Telangana, Andhra Pradesh         No
# 493                          Telangana, Andhra Pradesh         No
# 502                          Telangana, Andhra Pradesh         No
# 536                          Telangana, Andhra Pradesh         No
# 545                          Telangana, Andhra Pradesh        Yes
# 558                                         Tamil Nadu         No
# 587                                         Tamil Nadu         No
# 601                                         Tamil Nadu         No
# 612                                         Tamil Nadu         No
# 643                                         Tamil Nadu         No
# 652                                         Tamil Nadu        Yes
# 670                                        Maharashtra         No
# 692                                        Maharashtra         No
# 464       1                      10                          40
# 474       1                      16                          69
# 493       1                      15                          80
# 502       1                      15                          80
# 536       1                      15                          60
# 545       1                      12                          67
# 558       1                      14                          50
# 587       1                      15                          40
# 601       1                      15                          27
# 612       1                      15                          73
# 643       1                      15                          47
# 652       1                      10                          50
# 670       1                      14                          36
# 692       1                      14                          50
# 714       1                      14                          64
# 718       1                      13                          54
# 735       1                      14                          64
# 760       1                      14                          36
# 796       1                      14                          36
# 813       1                      14                          50

# %% [markdown]
# ## Bigg Boss India data set visualizations/infographics at Tableau Public -
# ## http://public.tableau.com/app/profile/satya.thirumani/viz/BiggBossIndia_16434338263440/BBStory

# %%
IFrame('https://public.tableau.com/views/BiggBossIndia_16434338263440/BBStory?:language=en-US&:display_count=n&:origin=viz_share_link', width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="https://public.tableau.com/views/BiggBossIndia_16434338263440/BBStory?:language=en-US&:display_count=n&:origin=viz_share_link"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Sum of prize money won by all BB Season winners/participants, in India
print(format_currency(bigg_boss['Prize Money (INR)'].sum(), 'INR', locale='en_IN').replace(".00", ""))

# 24 crores and 6 lakh rupees
# Out:
# ₹24,06,00,000

# %%
# Profession of BB Season Winners
bigg_boss.loc[bigg_boss.Winner==1, 'Profession'].value_counts()
# Out:
# Actor                  12
# Soap Actress            7
# Actress                 7
# Singer                  4
# Reality Show Alumni     3
# Soap Actor              3
# Commoner                2
# TV Anchor               2
# Model                   2
# Film Director           1
# Comedian                1
# Video Jockey            1
# Name: Profession, dtype: int64

# %%
# Gender of Season title Winners
print(bigg_boss.loc[bigg_boss.Winner==1, 'Gender'].value_counts(), '\n')

# In percentage
print(round(bigg_boss.loc[bigg_boss.Winner==1, 'Gender'].value_counts(normalize=True)*100).astype(str).str.replace('.0', '%'))

plt.figure(figsize=(15, 8))
ax1=plt.subplot(221)
bigg_boss.loc[bigg_boss.Winner==1, 'Gender'].value_counts().plot(kind='bar', color=["lightblue","pink"], ec="k")
plt.xlabel("Gender-wise BB Winners", fontsize=16)
plt.xticks(rotation=0, fontsize=16)
plt.setp(ax1.get_yticklabels(), visible=False)

for x,y in enumerate(bigg_boss.loc[bigg_boss.Winner==1, 'Gender'].value_counts()):
    plt.annotate(y,(x,y),fontsize=12,color="Red")
    
ax2=plt.subplot(222)
bigg_boss.loc[bigg_boss.Winner==1, 'Gender'].value_counts().plot(kind='pie',autopct='%.0f',explode = (0, 0.10),colors=["lightblue","pink"],shadow=True)
# Out:
# Male      31
# Female    14
# Name: Gender, dtype: int64
#
# Male      69%
# Female    31%
# Name: Gender, dtype: object
# <AxesSubplot:ylabel='Gender'>

# %% [markdown]
# ## No wild card entry housemate won the Bigg Boss competition.

# %%
# Entry type (wildcard or not) of the Season Winners
bigg_boss.loc[bigg_boss.Winner==1, 'Wild Card'].value_counts()
# Out:
# No    45
# Name: Wild Card, dtype: int64

# %%
bigg_boss.loc[bigg_boss.Winner==1, 'Season Length'].value_counts().sort_index()

# Length of the season - Number of Winners
# Out:
# 28      1
# 42      1
# 70      2
# 84      2
# 86      1
# 90      1
# 95      1
# 96      1
# 97      2
# 98     11
# 100     1
# 105    12
# 106     2
# 112     2
# 113     1
# 117     1
# 121     1
# 140     1
# 143     1
# Name: Season Length, dtype: int64

# %%
bigg_boss.loc[bigg_boss.Winner==1, 'Number of Housemates'].value_counts().sort_index()

# Number of Housemates in house - Number of Winners
# Out:
# 10     1
# 13     1
# 15     6
# 16     4
# 17     5
# 18    10
# 19     6
# 20     9
# 22     2
# 24     1
# Name: Number of Housemates, dtype: int64

# %%
# Number of eliminations or evictions faced by the Bigg Boss competition winners
bigg_boss.loc[bigg_boss.Winner==1, 'Number of Evictions Faced'].value_counts().sort_index()

# Number of eliminations faced - Number of Winners
# Out:
# 2     1
# 4     7
# 5     6
# 6     6
# 7     8
# 8     2
# 9     7
# 10    1
# 11    2
# 12    3
# 17    1
# Name: Number of Evictions Faced, dtype: Int64

# %%
# No re-entered contestant won Bigg Boss title
bigg_boss.loc[bigg_boss.Winner==1, 'Number of re-entries'].value_counts()
# Out:
# 0    45
# Name: Number of re-entries, dtype: Int64

# %%
# Bigg Boss title winners number of times elected as captain
bigg_boss.loc[bigg_boss.Winner==1, 'Number of times elected as Captain'].value_counts().sort_index()

# Number of times elected as Captain - Number of winners
# Out:
# 0    14
# 1    13
# 2    13
# 3     1
# 4     2
# Name: Number of times elected as Captain, dtype: Int64

# %%
# Word cloud of Bigg Boss
text = " BiggBoss ".join(cat for cat in bigg_boss['Language'])
wordcloud = WordCloud(width=2000, height=1500, background_color='Black', colormap='Spectral', collocations=False, random_state=2022).generate(text)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
print("Skewness: %f" % bigg_boss['Winner'].skew())
print("Kurtosis: %f" % bigg_boss['Winner'].kurt())
# Out:
# Skewness: 3.935924
# Kurtosis: 13.524197

# %%
# Correlation matrix (Heatmap style)
corrmat = bigg_boss.corr()
f, ax = plt.subplots(figsize=(17, 11))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(corrmat, vmax=1.0, linewidths=0.1, square=True, cmap="RdBu", linecolor='white', annot=True);

# %%
# Crosschecking Actor/Actress Gender
bigg_boss[bigg_boss['Profession'].str.contains('Act')].groupby('Gender')['Profession'].value_counts().unstack()
#bigg_boss.loc[(bigg_boss['Profession']=='Actress') & (bigg_boss['Gender']=='Male')]
# Out:
# Profession  Activist  Actor  Actor & Actress  Actress  Soap Actor  \
# Gender
# Couple           NaN    NaN              1.0      NaN         NaN
# Female           4.0    NaN              NaN    180.0         NaN
# Male             4.0  133.0              NaN      NaN        42.0
#
# Profession  Soap Actress  Stage Actress
# Gender
# Couple               NaN            NaN
# Female              67.0            2.0
# Male                 NaN            NaN

# %% [markdown]
# ## Machine Learning (ML) models to predict Indian BiggBoss (Big Brother) season Winners

# %% [markdown]
# ## Hindi Bigg Boss Season15
# ## https://www.kaggle.com/thirumani/predicting-bigg-boss-hindi-season-15-winner

# %% [markdown]
# ## Kannada Bigg Boss Season OTT
# ## https://www.kaggle.com/thirumani/predicting-bigg-boss-kannada-ott-season-winner

# %% [markdown]
# ## Tamil Bigg Boss Season 6
# ## https://www.kaggle.com/thirumani/predicting-bigg-boss-tamil-season-6-winner

# %% [markdown]
# ## Telugu Bigg Boss Season 6
# ## https://www.kaggle.com/thirumani/predicting-bigg-boss-telugu-season-6-winner

# %% [markdown]
# ## Malayalam Bigg Boss Season4
# ## https://www.kaggle.com/thirumani/predicting-bigg-boss-malayalam-season-4-winner

# %% [markdown]
# ## Marathi Bigg Boss Season3
# ## https://www.kaggle.com/thirumani/predicting-bigg-boss-marathi-season-3-winner

# %%
print("numpy version: {}". format(np.__version__))
print("pandas version: {}". format(pd.__version__))
import matplotlib
print("matplotlib version: {}". format(matplotlib. __version__))
print("seaborn version: {}". format(sns.__version__))
import sklearn
print("sklearn version: {}". format(sklearn.__version__))
import plotly
print("plotly version: {}". format(plotly.__version__))

# Current versions
# numpy version: 1.21.6
# pandas version: 1.3.5
# matplotlib version: 3.5.2
# seaborn version: 0.11.2
# sklearn version: 1.0.2
# plotly version: 5.9.0
# Out:
# numpy version: 1.21.6
# pandas version: 1.3.5
# matplotlib version: 3.5.2
# seaborn version: 0.11.2
# sklearn version: 1.0.2
# plotly version: 5.9.0
